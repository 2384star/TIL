# %%
import pandas as pd

# CSV 파일 경로
data4= pd.read_csv("./eda4.csv")

# CSV 파일을 pandas 데이터프레임으로 불러오기
sy_black = pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/DorospereBlack-이름변경.csv",encoding='utf-8')
sy_yellow=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/DorosperesYellow-이름변경.csv",encoding='utf-8')
sy_red=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/Dorosperse Red-이름변경.csv",encoding='utf-8')
sy_Blue=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/DorosperesBlue-이름변경.csv",encoding='utf-8')
sy_DarkGray=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/Dorosperse Brown-이름변경.csv",encoding='utf-8')

                      
# 데이터 확인

# %%
import math

def lab2rgb(l_s, a_s, b_s):
    var_Y = (l_s + 16) / 116.0
    var_X = a_s / 500.0 + var_Y
    var_Z = var_Y - b_s / 200.0

    if var_Y**3 > 0.008856:
        var_Y = var_Y**3
    else:
        var_Y = (var_Y - 16/116) / 7.787
    if var_X**3 > 0.008856:
        var_X = var_X**3
    else:
        var_X = (var_X - 16/116) / 7.787
    if var_Z**3 > 0.008856:
        var_Z = var_Z**3
    else:
        var_Z = (var_Z - 16/116) / 7.787

    X = 95.047 * var_X
    Y = 100.000 * var_Y
    Z = 108.883 * var_Z

    var_X = X / 100.0
    var_Y = Y / 100.0
    var_Z = Z / 100.0

    var_R = var_X * 3.2406 + var_Y * -1.5372 + var_Z * -0.4986
    var_G = var_X * -0.9689 + var_Y * 1.8758 + var_Z * 0.0415
    var_B = var_X * 0.0557 + var_Y * -0.2040 + var_Z * 1.0570

    if var_R > 0.0031308:
        var_R = 1.055 * (var_R ** (1/2.4)) - 0.055
    else:
        var_R = 12.92 * var_R
    if var_G > 0.0031308:
        var_G = 1.055 * (var_G ** (1/2.4)) - 0.055
    else:
        var_G = 12.92 * var_G
    if var_B > 0.0031308:
        var_B = 1.055 * (var_B ** (1/2.4)) - 0.055
    else:
        var_B = 12.92 * var_B

    R = var_R * 255.0
    G = var_G * 255.0
    B = var_B * 255.0

    return R, G, B

# 이 함수는 주어진 L*a*b* 값을 RGB 값으로 변환합니다.
# 예를 들어:
R, G, B = lab2rgb(25.42, 8.9475, -22.77125)
print(R, G, B)
# Out:
# 53.07723315495199 57.46896050808887 94.70754149923732

# %% [markdown]
# ### 사일론 회사는 5개밖에없어용 염료가~

# %%
# 'Synolon' 문자열을 포함하는 모든 컬럼을 조회합니다.
synolon_columns = data4.columns[data4.columns.str.contains("Synolon")]

# 조회된 컬럼 이름을 출력합니다.
print(synolon_columnss)
# Out:
# Index(['Lab 염색 상승속도 #1_std', 'Lab 염색 상승속도 #2_std', 'Lab 염색 상승속도 #3_std',
#        'Lab 염색 상승온도 #3_std', 'Lab 염색 상승온도 #3 유지시간_std', 'Lab 염색 하강속도 #1_std'],
#       dtype='object')

# %%
# 'Synolon' 문자열을 포함하는 모든 컬럼을 조회합니다.
bea_columns = data4.columns[data4.columns.str.contains("배합")]

# 조회된 컬럼 이름을 출력합니다.
print(bea_columns)
# Out:
# Index(['배합_Sunsolt RM-340S_std', '배합_빙초산_std', '배합_UVK-200_std',
#        '배합_Fadex® TS liq_std', '배합_UVK-400 H/C_std', '배합_Sera Fast P-UVC_std'],
#       dtype='object')

# %%
# 'Synolon' 문자열을 포함하는 모든 컬럼을 조회합니다.
synolon_columnss = data4.columns[data4.columns.str.contains("염색")]

# 조회된 컬럼 이름을 출력합니다.
print(synolon_columns)
# Out:
# Index(['Synolon Yellow AK_std', 'Synolon Red AK_std', 'Synolon Blue AK_std',
#        'Synolon Black AK-NB_std', 'Synolon Dark Grey AK_std',
#        'Synolon Yellow AK_prop_std', 'Synolon Red AK_prop_std',
#        'Synolon Blue AK_prop_std', 'Synolon Black AK-NB_prop_std',
#        'Synolon Dark Grey AK_prop_std'],
#       dtype='object')

# %%
sy_yellow= data4[data4["Synolon Yellow AK_std"] != 0]
sy_yellow["Synolon Yellow AK_std"].value_counts()
sy_yellow.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        2
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 20
# Synolon Red AK_std                    15
# Synolon Blue AK_std                   15
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_yellow[column].value_counts() for column in sy_yellow.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사블랙.csv", index=False)

# %%
sy_yellow_5= sy_yellow[sy_yellow["배합_빙초산_std"]==0.5]
sy_yellow_5.nunique()
# Out:
# 위사_소재명_enc                            1
# 경사_성상_비율 #3_std                       1
# 제직_중량_생지_std                          1
# 전처리_CH3COOH_std                       1
# Dorosperse Yellow KKL_std             1
# Dorosperse Red KKL_std                1
# Dorosperse Blue KKL_std               1
# Dianix Yellow AM-2R_std               1
# Dianix Red AM-SLR_std                 1
# Dianix Blue AM-2G_std                 1
# Synolon Yellow AK_std                15
# Synolon Red AK_std                   10
# Synolon Blue AK_std                  10
# Dorosperse B/K KKL_std                1
# Dianix Black AM-SLR_std               1
# Synolon Black AK-NB_std               1
# Dorosperse Dark Grey KKL_std          1
# Dianix Grey AM-SLR_std                1
# Synolon Dark Grey AK_std              1
# Dianix Yellow Brown AM-R_std          1
# Dorosperse Brown K-3LR_std            1
# Synofast 28_std                       1
# 배합_Sunsolt RM-340S_std                1
# ...

# %% [markdown]
# ### 결국 후처리 NaoH로 나뉜다는 결론이 된다
# ##### 후처리 0.5일때
# - 위경사 88 81
# - 재직중량생지 237
# - 전처리 ch3 0.5
# - 배합RM-3405S =0.3 <-확정 베합은 0.3밖에없음
# ##### ?????
# - #1상승속도 1.5
# - #2 상승속도 0.75
# - #3상승속도 1.45
# - #3 상승온도 135
# - #3 상승온도 유지시간 60
# - #3 염색하강온도 1.97
#
# #### 후처리 NaOH 1.5
# #### 후처리 Sera Con M-FAS_std 1.5

# %%
sy_yellow_5['Synolon Yellow AK_std'].value_counts()
# Out:
# Synolon Yellow AK_std
# 0.033    5
# 0.333    5
# 0.667    5
# 0.500    4
# 0.017    3
# 0.167    3
# 1.000    3
# 0.067    2
# 1.333    2
# 0.050    1
# 0.100    1
# 2.000    1
# 2.500    1
# 1.500    1
# 3.000    1
# Name: count, dtype: int64

# %%
sy_yellow_5.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 174                               0                                  0  \
# 175                               0                                  0
# 176                               0                                  0
# 177                               0                                  0
# 178                               0                                  0
# 179                               0                                  0
# 180                               0                                  0
# 181                               0                                  0
# 182                               0                                  0
# 183                               0                                  0
# 184                               0                                  0
# 185                               0                                  0
# ...

# %%
sy_yellow_5.iloc[:,10:20]
# Out:
#       Synolon Yellow AK_std  Synolon Red AK_std  Synolon Blue AK_std
# 174                   0.017               0.000                0.033  \
# 175                   0.017               0.017                0.017
# 176                   0.033               0.000                0.017
# 177                   0.033               0.000                0.067
# 178                   0.033               0.017                0.000
# 179                   0.033               0.067                0.000
# 180                   0.050               0.000                0.000
# 181                   0.067               0.000                0.033
# 182                   0.067               0.033                0.000
# 183                   0.100               0.000                0.000
# 184                   0.167               0.167                0.167
# 185                   0.167               0.333                0.000
# 186                   0.333               0.000                0.167
# ...

# %%
sy_yellow_5.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_yellow_5.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_yellow_5.iloc[:, 10:13]
df_from_center = sy_yellow_5.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사블랙_빙초산0.5.csv")

# %%
sy_yellow_52 = sy_yellow_5.iloc[:, -3:]

# %% [markdown]
# ### 유별의 가설
# - 1.혼합염료 기준으로 염료를 사용할때 L의 영향을 주는것은 1요소가 온도이다 특정온도값일때 L이 높은수치를 보임
# - 2. 혼합염료일때 단일염료가아닌 값은 B의 비율이 L의 수치를 낯춘다

# %%
import matplotlib.pyplot as plt
import numpy as np  # numpy 임포트 추가

# %%
rgb_list=[]
for index, row in sy_yellow_52.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=sy_yellow_52.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_y = pd.concat([sy_yellow_52, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_y[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_yellow_5[column].value_counts() for column in sy_yellow_5.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])
single_value_df
# Saving the DataFrame to an Excel file
#single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사블랙배합0.5.csv", index=False)
# Out:
#                           Column Name    Category
# 0                          위사_소재명_enc   88.000000
# 1                     경사_성상_비율 #3_std   81.000000
# 2                        제직_중량_생지_std  237.000000
# 3                     전처리_CH3COOH_std    0.500000
# 4           Dorosperse Yellow KKL_std    0.000000
# 5              Dorosperse Red KKL_std    0.000000
# 6             Dorosperse Blue KKL_std    0.000000
# 7             Dianix Yellow AM-2R_std    0.000000
# 8               Dianix Red AM-SLR_std    0.000000
# 9               Dianix Blue AM-2G_std    0.000000
# 10             Dorosperse B/K KKL_std    0.000000
# 11            Dianix Black AM-SLR_std    0.000000
# 12            Synolon Black AK-NB_std    0.000000
# 13       Dorosperse Dark Grey KKL_std    0.000000
# 14             Dianix Grey AM-SLR_std    0.000000
# 15           Synolon Dark Grey AK_std    0.000000
# 16       Dianix Yellow Brown AM-R_std    0.000000
# 17         Dorosperse Brown K-3LR_std    0.000000
# ...

# %%
sy_yellow_2= sy_yellow[sy_yellow["배합_빙초산_std"]==0.2]
sy_yellow_2.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        1
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 20
# Synolon Red AK_std                    15
# Synolon Blue AK_std                   15
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_yellow_2[column].value_counts() for column in sy_yellow_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
#single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사블랙배합0.2.csv", index=False)
# Out:
#               Column Name  Category
# 0         전처리_CH3COOH_std   1.00000
# 1  배합_Sunsolt RM-340S_std   0.30000
# 2              배합_빙초산_std   0.20000
# 3          배합_UVK-200_std   0.00000
# 4      Lab 염색 하강속도 #1_std   1.97222
# 5            후처리_NaOH_std   2.00000
# 6  후처리_Sera Con M-FAS_std   4.00000

# %%
sy_yellow_2_1= sy_yellow[sy_yellow["위사_소재명_enc"]==88]
sy_yellow_2_2= sy_yellow[sy_yellow["위사_소재명_enc"]==96]

# %%
sy_yellow_2_1.nunique()
# Out:
# 위사_소재명_enc                             1
# 경사_성상_비율 #3_std                        1
# 제직_중량_생지_std                           2
# 전처리_CH3COOH_std                        2
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 20
# Synolon Red AK_std                    15
# Synolon Blue AK_std                   15
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_yellow_2_1['Synolon Yellow AK_std'].value_counts()
# Out:
# Synolon Yellow AK_std
# 1.000    13
# 0.667    10
# 2.000    10
# 0.033    10
# 0.333    10
# 0.500     8
# 1.333     7
# 4.000     7
# 0.017     6
# 0.167     6
# 6.000     5
# 0.067     4
# 0.833     3
# 0.100     2
# 2.500     2
# 1.500     2
# 1.667     2
# 2.667     2
# 3.000     2
# 0.050     2
# Name: count, dtype: int64

# %%
sy_yellow_2_2['Synolon Yellow AK_std'].value_counts()
# Out:
# Synolon Yellow AK_std
# 2.000    60
# 0.033    50
# 0.333    50
# 0.667    50
# 1.333    50
# 1.000    37
# 0.017    30
# 0.167    30
# 4.000    30
# 0.067    20
# 2.667    20
# 0.050    10
# 0.100    10
# 0.500    10
# 3.000    10
# 6.000    10
# Name: count, dtype: int64

# %% [markdown]
# ### 즉 위경사 88 일때는 온도를 맟춰쓰는거구만?

# %%
sy_yellow_2_1.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 174                               0                                  0  \
# 175                               0                                  0
# 176                               0                                  0
# 177                               0                                  0
# 178                               0                                  0
# ...                             ...                                ...
# 3424                              0                                  0
# 3425                              0                                  0
# 3426                              0                                  0
# 3427                              0                                  0
# 3497                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std    색상_L*    색상_a*
# ...

# %%
sy_yellow_2_1.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_yellow_2_1.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_yellow_2_1.iloc[:, 10:13]
df_from_center = sy_yellow_2_1.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사블랙_빙초산0.2_위사88.csv")

# %%
sy_yellow_2_2.nunique()
# Out:
# 위사_소재명_enc                             1
# 경사_성상_비율 #3_std                        1
# 제직_중량_생지_std                           1
# 전처리_CH3COOH_std                        1
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 16
# Synolon Red AK_std                    12
# Synolon Blue AK_std                   12
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_yellow_2_2.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_yellow_2_2.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_yellow_2_2.iloc[:, 10:13]
df_from_center = sy_yellow_2_2.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사블랙_빙초산0.2_위사96.csv")

# %%
sy_yellow6=data4[data4["Synolon Yellow AK_std"] >= 6.0]
sy_yellow6.nunique()
sy_yellow6.iloc[:,50:60]
sy_yellow6.iloc[:,27:35]
# Out:
#       배합_Sera Fast P-UVC_std  Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std
# 615                        0                 1.5                0.75  \
# 1250                       0                 1.5                0.75
# 1251                       2                 1.5                0.75
# 1252                       3                 1.5                0.75
# 1253                       4                 1.5                0.75
# 2917                       0                 1.5                0.75
# 2918                       0                 1.5                0.75
# 2919                       0                 1.5                0.75
# 2920                       0                 1.5                0.75
# 2921                       0                 1.5                0.75
# 2922                       0                 1.5                0.75
# 2923                       0                 1.5                0.75
# 2924                       0                 1.5                0.75
# ...

# %% [markdown]
# ## 의도적으로 만든 2917

# %%
sy_yellow6.iloc[:,50:60]
#의도적으로 만든 2917
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 615                               0                                  0  \
# 1250                              0                                  0
# 1251                              0                                  0
# 1252                              0                                  0
# 1253                              0                                  0
# 2917                              0                                  0
# 2918                              0                                  0
# 2919                              0                                  0
# 2920                              0                                  0
# 2921                              0                                  0
# 2922                              0                                  0
# 2923                              0                                  0
# ...

# %%
sy_yellow6.iloc[:,27:35]
# Out:
#       배합_Sera Fast P-UVC_std  Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std
# 615                        0                 1.5                0.75  \
# 1250                       0                 1.5                0.75
# 1251                       2                 1.5                0.75
# 1252                       3                 1.5                0.75
# 1253                       4                 1.5                0.75
# 2917                       0                 1.5                0.75
# 2918                       0                 1.5                0.75
# 2919                       0                 1.5                0.75
# 2920                       0                 1.5                0.75
# 2921                       0                 1.5                0.75
# 2922                       0                 1.5                0.75
# 2923                       0                 1.5                0.75
# 2924                       0                 1.5                0.75
# ...

# %% [markdown]
# ### 여기서부터 블루

# %%
sy_bule= data4[data4["Synolon Blue AK_std"] != 0]
sy_bule["Synolon Blue AK_std"].value_counts()
sy_bule.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        2
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 15
# Synolon Red AK_std                    15
# Synolon Blue AK_std                   20
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_bule2=data4[data4["Synolon Blue AK_std"] >= 6.0]
sy_bule2.nunique()
sy_bule2
sy_bule2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 537                               0                                  0  \
# 1224                              0                                  0
# 1225                              0                                  0
# 1226                              0                                  0
# 1227                              0                                  0
# 2272                              0                                  0
# 2273                              0                                  0
# 2274                              0                                  0
# 2275                              0                                  0
# 2276                              0                                  0
# 2277                              0                                  0
# 2278                              0                                  0
# ...

# %% [markdown]
# ## 의도적으로 만든 2272|

# %%
sy_bule2.iloc[:,27:35]
sy_bule2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 537                               0                                  0  \
# 1224                              0                                  0
# 1225                              0                                  0
# 1226                              0                                  0
# 1227                              0                                  0
# 2272                              0                                  0
# 2273                              0                                  0
# 2274                              0                                  0
# 2275                              0                                  0
# 2276                              0                                  0
# 2277                              0                                  0
# 2278                              0                                  0
# ...

# %%
sy_bule2.iloc[:, 10:13]
# Out:
#       Synolon Yellow AK_std  Synolon Red AK_std  Synolon Blue AK_std
# 537                     0.0                 0.0                  6.0
# 1224                    0.0                 0.0                  6.0
# 1225                    0.0                 0.0                  6.0
# 1226                    0.0                 0.0                  6.0
# 1227                    0.0                 0.0                  6.0
# 2272                    0.0                 0.0                  6.0
# 2273                    0.0                 0.0                  6.0
# 2274                    0.0                 0.0                  6.0
# 2275                    0.0                 0.0                  6.0
# 2276                    0.0                 0.0                  6.0
# 2277                    0.0                 0.0                  6.0
# 2278                    0.0                 0.0                  6.0
# 3602                    0.0                 0.0                  6.0
# ...

# %%
sy_bule2.iloc[:,27:35]
# Out:
#       배합_Sera Fast P-UVC_std  Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std
# 537                        0                 1.5                0.75  \
# 1224                       0                 1.5                0.75
# 1225                       2                 1.5                0.75
# 1226                       3                 1.5                0.75
# 1227                       4                 1.5                0.75
# 2272                       0                 1.5                0.75
# 2273                       0                 1.5                0.75
# 2274                       0                 1.5                0.75
# 2275                       0                 1.5                0.75
# 2276                       0                 1.5                0.75
# 2277                       0                 1.5                0.75
# 2278                       0                 1.5                0.75
# 3602                       0                 1.5                0.75
# ...

# %% [markdown]
# ### 너도 빙초산으로 나눌깨

# %%
sy_bule_2= sy_bule[sy_bule["배합_빙초산_std"]==0.2]
sy_bule_2.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        1
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 15
# Synolon Red AK_std                    15
# Synolon Blue AK_std                   20
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_bule_2[column].value_counts() for column in sy_bule_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사배합블루0.2.csv", index=False)

# %%
sy_bule_2_1= sy_bule_2[sy_bule_2["위사_소재명_enc"]==88]
sy_bule_2_2= sy_bule_2[sy_bule_2["위사_소재명_enc"]==96]

# %%
sy_bule_2_1.nunique()
# Out:
# 위사_소재명_enc                            1
# 경사_성상_비율 #3_std                       1
# 제직_중량_생지_std                          2
# 전처리_CH3COOH_std                       1
# Dorosperse Yellow KKL_std             1
# Dorosperse Red KKL_std                1
# Dorosperse Blue KKL_std               1
# Dianix Yellow AM-2R_std               1
# Dianix Red AM-SLR_std                 1
# Dianix Blue AM-2G_std                 1
# Synolon Yellow AK_std                15
# Synolon Red AK_std                   15
# Synolon Blue AK_std                  20
# Dorosperse B/K KKL_std                1
# Dianix Black AM-SLR_std               1
# Synolon Black AK-NB_std               1
# Dorosperse Dark Grey KKL_std          1
# Dianix Grey AM-SLR_std                1
# Synolon Dark Grey AK_std              1
# Dianix Yellow Brown AM-R_std          1
# Dorosperse Brown K-3LR_std            1
# Synofast 28_std                       1
# 배합_Sunsolt RM-340S_std                1
# ...

# %% [markdown]
# ### 결론은 위사 88의 온도는 정해졋다

# %%
sy_bule_2_1.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_bule_2_1.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_bule_2_1.iloc[:, 10:13]
df_from_center = sy_bule_2_1.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블루/sy회사블루_빙초산0.2_위사88.csv")

# %%
sy_bule_2_2.nunique()
# Out:
# 위사_소재명_enc                             1
# 경사_성상_비율 #3_std                        1
# 제직_중량_생지_std                           1
# 전처리_CH3COOH_std                        1
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 12
# Synolon Red AK_std                    12
# Synolon Blue AK_std                   16
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_bule_2_1.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_bule_2_2.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_bule_2_2.iloc[:, 10:13]
df_from_center = sy_bule_2_2.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블루/sy회사블루_빙초산0.2_위사96.csv")

# %% [markdown]
# ### 회사 블루 빙초산 0.2 빙초산 96 꼭참고해주세요

# %%
sy_bule_5=sy_bule[sy_bule["배합_빙초산_std"]==0.5]
sy_bule_5.nunique()
# Out:
# 위사_소재명_enc                            1
# 경사_성상_비율 #3_std                       1
# 제직_중량_생지_std                          1
# 전처리_CH3COOH_std                       1
# Dorosperse Yellow KKL_std             1
# Dorosperse Red KKL_std                1
# Dorosperse Blue KKL_std               1
# Dianix Yellow AM-2R_std               1
# Dianix Red AM-SLR_std                 1
# Dianix Blue AM-2G_std                 1
# Synolon Yellow AK_std                10
# Synolon Red AK_std                   10
# Synolon Blue AK_std                  15
# Dorosperse B/K KKL_std                1
# Dianix Black AM-SLR_std               1
# Synolon Black AK-NB_std               1
# Dorosperse Dark Grey KKL_std          1
# Dianix Grey AM-SLR_std                1
# Synolon Dark Grey AK_std              1
# Dianix Yellow Brown AM-R_std          1
# Dorosperse Brown K-3LR_std            1
# Synofast 28_std                       1
# 배합_Sunsolt RM-340S_std                1
# ...

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_bule_5[column].value_counts() for column in sy_bule_5.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/sy회사배합블루0.5.csv", index=False)

# %%
sy_bule_5.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_bule_5.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_bule_5.iloc[:, 10:13]
df_from_center = sy_bule_5.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블루/sy회사블루_빙초산0.5.csv")

# %% [markdown]
# ### 이제 레드한다

# %%
sy_red= data4[data4["Synolon Red AK_std"] != 0]
sy_red["Synolon Red AK_std"].value_counts()
# Out:
# Synolon Red AK_std
# 2.000    70
# 0.333    60
# 0.667    60
# 0.033    60
# 1.333    57
# 1.000    50
# 4.000    37
# 0.017    36
# 0.167    36
# 0.067    24
# 2.667    22
# 0.500    18
# 6.000    15
# 3.000    12
# 0.100    12
# 0.050    12
# 0.833     3
# 1.667     2
# 2.500     2
# 1.500     2
# Name: count, dtype: int64

# %%
sy_red.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        2
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 15
# Synolon Red AK_std                    20
# Synolon Blue AK_std                   15
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %% [markdown]
# ### 2484 특이값

# %%
sy_red2=data4[data4["Synolon Red AK_std"] >= 6.0]
sy_red2.nunique()
sy_red2
sy_red2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 564                               0                                  0  \
# 1236                              0                                  0
# 1237                              0                                  0
# 1238                              0                                  0
# 2484                              0                                  0
# 2485                              0                                  0
# 2486                              0                                  0
# 2487                              0                                  0
# 2488                              0                                  0
# 2489                              0                                  0
# 2490                              0                                  0
# 2491                              0                                  0
# ...

# %%
sy_red2.iloc[:,50:60]
sy_red2.iloc[:,27:35]
# Out:
#       배합_Sera Fast P-UVC_std  Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std
# 564                        0                 1.5                0.75  \
# 1236                       0                 1.5                0.75
# 1237                       2                 1.5                0.75
# 1238                       3                 1.5                0.75
# 2484                       0                 1.5                0.75
# 2485                       0                 1.5                0.75
# 2486                       0                 1.5                0.75
# 2487                       0                 1.5                0.75
# 2488                       0                 1.5                0.75
# 2489                       0                 1.5                0.75
# 2490                       0                 1.5                0.75
# 2491                       0                 1.5                0.75
# 2492                       0                 1.5                0.75
# ...

# %% [markdown]
# ### 너또한 빙초산으로 나눈다

# %%
sy_red_2= sy_red[sy_red["배합_빙초산_std"]==0.2]
sy_red_2.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        1
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                 15
# Synolon Red AK_std                    20
# Synolon Blue AK_std                   15
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_red_2["제직_중량_생지_std"].value_counts()
# Out:
# 제직_중량_생지_std
# 236    477
# 237     59
# 242     16
# Name: count, dtype: int64

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_2[column].value_counts() for column in sy_red_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.2.csv", index=False)

# %%
sy_red_2_1= sy_red_2[sy_red_2["위사_소재명_enc"]==88]
sy_red_2_2= sy_red_2[sy_red_2["위사_소재명_enc"]==96]

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_2_1[column].value_counts() for column in sy_red_2_1.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.2_88.csv", index=False)

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_2_2[column].value_counts() for column in sy_red_2_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.2_96.csv", index=False)

# %%
sy_red_2_1_237= sy_red_2_1[sy_red_2_1["제직_중량_생지_std"]==237]
sy_red_2_1_242= sy_red_2_1[sy_red_2_1["제직_중량_생지_std"]==242]

# %% [markdown]
# #### 레드의 빙초산 0.2의 위사소재 88 기준으로 제직 중량생지 2개의 차이를보자

# %%
sy_red_2_1["제직_중량_생지_std"].value_counts()
# Out:
# 제직_중량_생지_std
# 237    59
# 242    16
# Name: count, dtype: int64

# %% [markdown]
# ## 빙초산 0.2에서는 각각 온도가 정해져잇음 제직에따라

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_2_1_237[column].value_counts() for column in sy_red_2_1_237.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
#single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.2_88_237.csv", index=False)
# Out:
#                           Column Name    Category
# 0                          위사_소재명_enc   88.000000
# 1                     경사_성상_비율 #3_std   81.000000
# 2                        제직_중량_생지_std  237.000000
# 3                     전처리_CH3COOH_std    1.000000
# 4           Dorosperse Yellow KKL_std    0.000000
# 5              Dorosperse Red KKL_std    0.000000
# 6             Dorosperse Blue KKL_std    0.000000
# 7             Dianix Yellow AM-2R_std    0.000000
# 8               Dianix Red AM-SLR_std    0.000000
# 9               Dianix Blue AM-2G_std    0.000000
# 10             Dorosperse B/K KKL_std    0.000000
# 11            Dianix Black AM-SLR_std    0.000000
# 12            Synolon Black AK-NB_std    0.000000
# 13       Dorosperse Dark Grey KKL_std    0.000000
# 14             Dianix Grey AM-SLR_std    0.000000
# 15           Synolon Dark Grey AK_std    0.000000
# 16       Dianix Yellow Brown AM-R_std    0.000000
# 17         Dorosperse Brown K-3LR_std    0.000000
# ...

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_2_1_242[column].value_counts() for column in sy_red_2_1_242.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
#single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.2_88_242.csv", index=False)
# Out:
#                           Column Name    Category
# 0                          위사_소재명_enc   88.000000
# 1                     경사_성상_비율 #3_std   81.000000
# 2                        제직_중량_생지_std  242.000000
# 3                     전처리_CH3COOH_std    1.000000
# 4           Dorosperse Yellow KKL_std    0.000000
# 5              Dorosperse Red KKL_std    0.000000
# 6             Dorosperse Blue KKL_std    0.000000
# 7             Dianix Yellow AM-2R_std    0.000000
# 8               Dianix Red AM-SLR_std    0.000000
# 9               Dianix Blue AM-2G_std    0.000000
# 10              Synolon Yellow AK_std    0.000000
# 11                Synolon Blue AK_std    0.000000
# 12             Dorosperse B/K KKL_std    0.000000
# 13            Dianix Black AM-SLR_std    0.000000
# 14            Synolon Black AK-NB_std    0.000000
# 15       Dorosperse Dark Grey KKL_std    0.000000
# 16             Dianix Grey AM-SLR_std    0.000000
# 17           Synolon Dark Grey AK_std    0.000000
# ...

# %% [markdown]
# ### 두값온도비교 드가자

# %%
sy_red_2_1_237.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_red_2_1_237.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_red_2_1_237.iloc[:, 10:13]
df_from_center = sy_red_2_1_237.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사레드_빙초산0.2_88_237.csv")

# %%
sy_red_2_1_242.iloc[:,20:40]
# sy_yellow_5라는 데이터프레임에서 특정 컬럼을 추출하여 새로운 데이터프레임을 생성합니다.

# 뒤에서 3개의 컬럼 추출
df_from_end = sy_red_2_1_242.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_red_2_1_242.iloc[:, 10:13]
df_from_center = sy_red_2_1_242.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사레드_빙초산0.2_88_242.csv")

# %% [markdown]
# ### 빙초산 0.2 에서 위사88 _242이 모두 단일염료로쓰인다 근대 왜 값이 안똑같지?

# %%
red_sp=sy_red_2_1_242[sy_red_2_1_242["Synolon Red AK_std"]==4.0]
red_sp.nunique()
# Out:
# 위사_소재명_enc                           1
# 경사_성상_비율 #3_std                      1
# 제직_중량_생지_std                         1
# 전처리_CH3COOH_std                      1
# Dorosperse Yellow KKL_std            1
# Dorosperse Red KKL_std               1
# Dorosperse Blue KKL_std              1
# Dianix Yellow AM-2R_std              1
# Dianix Red AM-SLR_std                1
# Dianix Blue AM-2G_std                1
# Synolon Yellow AK_std                1
# Synolon Red AK_std                   1
# Synolon Blue AK_std                  1
# Dorosperse B/K KKL_std               1
# Dianix Black AM-SLR_std              1
# Synolon Black AK-NB_std              1
# Dorosperse Dark Grey KKL_std         1
# Dianix Grey AM-SLR_std               1
# Synolon Dark Grey AK_std             1
# Dianix Yellow Brown AM-R_std         1
# Dorosperse Brown K-3LR_std           1
# Synofast 28_std                      1
# 배합_Sunsolt RM-340S_std               1
# 배합_빙초산_std                           1
# ...

# %%
red_sp.iloc[:,27:40]
# Out:
#       배합_Sera Fast P-UVC_std  Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std
# 1232                       0                 1.5                0.75  \
# 1233                       2                 1.5                0.75
# 1234                       3                 1.5                0.75
# 1235                       4                 1.5                0.75
#
#       Lab 염색 상승속도 #3_std  Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std
# 1232            1.458333                 135                       60  \
# 1233            1.458333                 135                       60
# 1234            1.458333                 135                       60
# 1235            1.458333                 135                       60
#
#       Lab 염색 하강속도 #1_std  후처리_NaOH_std  후처리_Sera Con M-FAS_std
# 1232             1.97222           2.0                     4.0  \
# 1233             1.97222           2.0                     4.0
# 1234             1.97222           2.0                     4.0
# ...

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = red_sp.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = red_sp.iloc[:, 10:13]
df_from_center = red_sp.iloc[:,27]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/배합비율에따른변화.csv")

# %%
sy_red_2_1_242["배합_Sera Fast P-UVC_std"]
# Out:
# 1228    2
# 1229    3
# 1230    2
# 1231    4
# 1232    0
# 1233    2
# 1234    3
# 1235    4
# 1236    0
# 1237    2
# 1238    3
# 3492    0
# 3493    4
# 3494    0
# 3495    3
# 3496    4
# Name: 배합_Sera Fast P-UVC_std, dtype: int64

# %% [markdown]
# ### 이제 위사 96 을봐야지?

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_2_2[column].value_counts() for column in sy_red_2_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.2_96.csv", index=False)

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = sy_red_2_2.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_red_2_2.iloc[:, 10:13]
df_from_center = sy_red_2_2.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사레드_빙초산0.2_96.csv")

# %% [markdown]
# ### sy회사레드_빙초산0.2_96 파일 시트2확인시켜주기

# %% [markdown]
# ### 빙초산 0.5 하고 합성염료끝

# %%
sy_red_5= sy_red[sy_red["배합_빙초산_std"]==0.5]

# %%
sy_red_5.nunique()
# Out:
# 위사_소재명_enc                            1
# 경사_성상_비율 #3_std                       1
# 제직_중량_생지_std                          1
# 전처리_CH3COOH_std                       1
# Dorosperse Yellow KKL_std             1
# Dorosperse Red KKL_std                1
# Dorosperse Blue KKL_std               1
# Dianix Yellow AM-2R_std               1
# Dianix Red AM-SLR_std                 1
# Dianix Blue AM-2G_std                 1
# Synolon Yellow AK_std                10
# Synolon Red AK_std                   15
# Synolon Blue AK_std                  10
# Dorosperse B/K KKL_std                1
# Dianix Black AM-SLR_std               1
# Synolon Black AK-NB_std               1
# Dorosperse Dark Grey KKL_std          1
# Dianix Grey AM-SLR_std                1
# Synolon Dark Grey AK_std              1
# Dianix Yellow Brown AM-R_std          1
# Dorosperse Brown K-3LR_std            1
# Synofast 28_std                       1
# 배합_Sunsolt RM-340S_std                1
# ...

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_red_5[column].value_counts() for column in sy_red_5.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사배합레드0.5.csv", index=False)

# %% [markdown]
# ### 빙초산 0.5 도한 온도규격이 정해져있음

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = sy_red_5.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_red_5.iloc[:, 10:13]
df_from_center = sy_red_5.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/레드/sy회사레드_빙초산0.5.csv")

# %% [markdown]
# ### 코멘트 레드, 블루 이두개가 높으면 L을 낯춰줌

# %% [markdown]
# ### 이제 단일염료 하고 끝!

# %%
sy_black= data4[data4["Synolon Black AK-NB_std"] != 0]
sy_black["Synolon Black AK-NB_std"].value_counts()
sy_black.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        2
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                  1
# Synolon Red AK_std                     1
# Synolon Blue AK_std                    1
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std               11
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std               1
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_black_sp= data4[data4["Synolon Black AK-NB_std"] == 6]
sy_black_sp["Synolon Black AK-NB_std"].value_counts()
sy_black_sp
# Out:
#       위사_소재명_enc  경사_성상_비율 #3_std  제직_중량_생지_std  전처리_CH3COOH_std
# 113           88               81           237              0.5  \
# 114           88               81           237              0.5
# 467           88               81           237              1.0
# 1141          88               81           242              1.0
# 1142          88               81           242              1.0
# 1143          88               81           242              1.0
# 1144          88               81           242              1.0
# 2190          96               72           236              1.0
# 2191          96               72           236              1.0
# 2192          96               72           236              1.0
# 2193          96               72           236              1.0
# 2194          96               72           236              1.0
# 2195          96               72           236              1.0
# ...

# %%
sy_black_sp.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 113                               0                                  0  \
# 114                               0                                  0
# 467                               0                                  0
# 1141                              0                                  0
# 1142                              0                                  0
# 1143                              0                                  0
# 1144                              0                                  0
# 2190                              0                                  0
# 2191                              0                                  0
# 2192                              0                                  0
# 2193                              0                                  0
# 2194                              0                                  0
# ...

# %% [markdown]
# ### 특이값 2190

# %%
sy_black_sp.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 113                  1.5                0.75            1.500000  \
# 114                  1.5                0.75            1.500000
# 467                  1.5                0.75            1.458333
# 1141                 1.5                0.75            1.458333
# 1142                 1.5                0.75            1.458333
# 1143                 1.5                0.75            1.458333
# 1144                 1.5                0.75            1.458333
# 2190                 1.5                0.75            0.833333
# 2191                 1.5                0.75            1.250000
# 2192                 1.5                0.75            1.458333
# 2193                 1.5                0.75            1.458333
# 2194                 1.5                0.75            1.458333
# 2195                 1.5                0.75            1.458333
# ...

# %% [markdown]
# ### 너도 결국 빙초산을 써야하는구나 ..

# %%
sy_black2= sy_black[sy_black["배합_빙초산_std"]==0.2]
sy_black2_1=sy_black2[sy_black2["위사_소재명_enc"]==88]
sy_black2_2=sy_black2[sy_black2["위사_소재명_enc"]==96]

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_black2_1[column].value_counts() for column in sy_black2_1.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사배합블렉0.2_88.csv", index=False)

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_black2_2[column].value_counts() for column in sy_black2_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사배합블렉0.2_96.csv", index=False)

# %%
sy_black2_1_237= sy_black2_1[sy_black2_1["제직_중량_생지_std"]==237]
sy_black2_1_242= sy_black2_1[sy_black2_1["제직_중량_생지_std"]==242]

# %% [markdown]
# ### 위경사 88 제직에따라나눈다

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_black2_1_237[column].value_counts() for column in sy_black2_1_237.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사배합블렉0.2_88_237.csv", index=False)

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_black2_1_242[column].value_counts() for column in  sy_black2_1_242.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사배합블렉0.2_88_242.csv", index=False)

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = sy_black2_1_237.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_black2_1_237.iloc[:, 15]
df_from_center = sy_black2_1_237.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사블렉_빙초산0.2_88_237.csv")

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = sy_black2_1_242.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_black2_1_242.iloc[:, 15]
df_from_center = sy_black2_1_242.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사블렉_빙초산0.2_88_242.csv")

# %% [markdown]
# ## 위경사 96도해야지

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = sy_black2_2.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_black2_2.iloc[:, 15]
df_from_center = sy_black2_2.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/블렉/sy회사블렉_빙초산0.2_96.csv")

# %% [markdown]
# ### 이제 다크그레이하자

# %%
sy_DarkGray= data4[data4["Synolon Dark Grey AK_std"] != 0]
sy_DarkGray["Synolon Dark Grey AK_std"].value_counts()
# Out:
# Synolon Dark Grey AK_std
# 4.00    18
# 6.00    18
# 1.00    17
# 2.00    17
# 3.00    13
# 0.10    11
# 0.50    11
# 0.05    11
# 5.00     3
# 1.50     1
# 2.50     1
# Name: count, dtype: int64

# %%
sy_DarkGray.nunique()
# Out:
# 위사_소재명_enc                             2
# 경사_성상_비율 #3_std                        2
# 제직_중량_생지_std                           3
# 전처리_CH3COOH_std                        2
# Dorosperse Yellow KKL_std              1
# Dorosperse Red KKL_std                 1
# Dorosperse Blue KKL_std                1
# Dianix Yellow AM-2R_std                1
# Dianix Red AM-SLR_std                  1
# Dianix Blue AM-2G_std                  1
# Synolon Yellow AK_std                  1
# Synolon Red AK_std                     1
# Synolon Blue AK_std                    1
# Dorosperse B/K KKL_std                 1
# Dianix Black AM-SLR_std                1
# Synolon Black AK-NB_std                1
# Dorosperse Dark Grey KKL_std           1
# Dianix Grey AM-SLR_std                 1
# Synolon Dark Grey AK_std              11
# Dianix Yellow Brown AM-R_std           1
# Dorosperse Brown K-3LR_std             1
# Synofast 28_std                        1
# 배합_Sunsolt RM-340S_std                 1
# ...

# %%
sy_DarkGray_sp= data4[data4["Synolon Dark Grey AK_std"] == 6]
sy_DarkGray_sp["Synolon Dark Grey AK_std"].value_counts()
# Out:
# Synolon Dark Grey AK_std
# 6.0    18
# Name: count, dtype: int64

# %% [markdown]
# ### 특이값 2106

# %%
sy_DarkGray_sp.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 63                   1.5                0.75            1.500000  \
# 64                   1.5                0.75            1.500000
# 65                   1.5                0.75            1.500000
# 402                  1.5                0.75            1.458333
# 1054                 1.5                0.75            1.458333
# 1055                 1.5                0.75            1.458333
# 1056                 1.5                0.75            1.458333
# 1057                 1.5                0.75            1.458333
# 2106                 1.5                0.75            0.833333
# 2107                 1.5                0.75            1.250000
# 2108                 1.5                0.75            1.458333
# 2109                 1.5                0.75            1.458333
# 2110                 1.5                0.75            1.458333
# ...

# %%
sy_DarkGray_sp.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 63                                1                                  0  \
# 64                                1                                  0
# 65                                1                                  0
# 402                               1                                  0
# 1054                              1                                  0
# 1055                              1                                  0
# 1056                              1                                  0
# 1057                              1                                  0
# 2106                              1                                  0
# 2107                              1                                  0
# 2108                              1                                  0
# 2109                              1                                  0
# ...

# %% [markdown]
# ## 너도 빙초산이냐 ...

# %%
sy_DarkGray2=sy_DarkGray[sy_DarkGray["배합_빙초산_std"]==0.2]
sy_DarkGray2_1=sy_DarkGray2[sy_DarkGray2["위사_소재명_enc"]==88]
sy_DarkGray2_2=sy_DarkGray2[sy_DarkGray2["위사_소재명_enc"]==96]

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_DarkGray2_1[column].value_counts() for column in sy_DarkGray2_1.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사배합다크그레이0.2_88.csv", index=False)

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_DarkGray2_2[column].value_counts() for column in sy_DarkGray2_2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사배합다크그레이0.2_96.csv", index=False)

# %%
sy_DarkGray2_1_237= sy_DarkGray2_1[sy_DarkGray2_1["제직_중량_생지_std"]==237]
sy_DarkGray2_1_242= sy_DarkGray2_1[sy_DarkGray2_1["제직_중량_생지_std"]==242]

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_DarkGray2_1_237[column].value_counts() for column in sy_DarkGray2_1_237.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사배합다크그레이0.2_88_237.csv", index=False)

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_DarkGray2_1_242[column].value_counts() for column in sy_DarkGray2_1_242.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사배합다크그레이0.2_88_242.csv", index=False)

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end =  sy_DarkGray2_1_237.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front =  sy_DarkGray2_1_237.iloc[:, 18]
df_from_center =  sy_DarkGray2_1_237.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사다크그레이_빙초산0.2_88_237.csv")

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end =  sy_DarkGray2_1_242.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front =  sy_DarkGray2_1_242.iloc[:, 18]
df_from_center =  sy_DarkGray2_1_242.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사다크그레이_빙초산0.2_88_242.csv")

# %% [markdown]
# ### 위경사 96

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end =  sy_DarkGray2_2.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front =  sy_DarkGray2_2.iloc[:, 18]
df_from_center =  sy_DarkGray2_2.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사다크그레이_빙초산0.2_96.csv")

# %%
sy_DarkGray_5=sy_DarkGray[sy_DarkGray["배합_빙초산_std"]==0.5]

# %%
# 가정: dix_YB는 이미 정의된 pandas DataFrame입니다.
import pandas as pd

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: sy_DarkGray_5[column].value_counts() for column in sy_DarkGray_5.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

# Converting the result to a DataFrame
single_value_df = pd.DataFrame(list(single_value_columns_formatted.items()), columns=['Column Name', 'Category'])

single_value_df
# Saving the DataFrame to an Excel file
single_value_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사배합다크그레이0.5.csv", index=False)

# %%
# 뒤에서 3개의 컬럼 추출
df_from_end = sy_DarkGray_5.iloc[:, -3:]

# 앞에서 10번째부터 19번째 컬럼까지 추출 (파이썬의 인덱싱은 0부터 시작하므로 10:20이 11번째부터 20번째 컬럼을 의미합니다.)
df_from_front = sy_DarkGray_5.iloc[:, 18]
df_from_center = sy_DarkGray_5.iloc[:, 28:34]

# 두 데이터프레임을 합칩니다.
combined_df = pd.concat([df_from_front,df_from_center, df_from_end], axis=1)

# combined_df의 기본적인 통계적 특징을 확인합니다.


combined_df.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/다크그레이/sy회사다크그레이_빙초산0.5.csv")

# %% [markdown]
# ### 용어정리
#
# ###### Sunsolt RM-340S":  폴리에스터 섬유의 저액비 및 빠른 염색을 위한 분산제/평준제
# - 어려운염료와 보조제를 분산시키는 기능 어려운 색상의 정밀한 음영제어를 위한 지연형 평준화

# %% [markdown]
# ##### : Fadex® TS liq" 정보를 찾을수없음

# %% [markdown]
# ##### 배합_Sera Fast P-UVC_std:
