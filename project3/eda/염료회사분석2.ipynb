# %%
import pandas as pd

# CSV 파일 경로
data4= pd.read_csv("./eda4.csv")

# CSV 파일을 pandas 데이터프레임으로 불러오기
dix_black = pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/DorospereBlack-이름변경.csv",encoding='utf-8')
dix_yellow=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/DorosperesYellow-이름변경.csv",encoding='utf-8')
dix_red=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/Dorosperse Red-이름변경.csv",encoding='utf-8')
dix_Blue=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/DorosperesBlue-이름변경.csv",encoding='utf-8')
dix_Gray=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/Dorosperse Brown-이름변경.csv",encoding='utf-8')
dix_Ygrey=pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/Dorosperse분석/Dorosperse DarkGrey-이름변경.csv")
                      
# 데이터 확인

# %% [markdown]
# ### 여기 잠깐 바꾼다

# %%
train = pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/기초데이터/train_data.csv", encoding='euc-kr')
test = pd.read_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/기초데이터/test_data.csv", encoding='euc-kr')

data4 = pd.concat([train, test], axis=0)

# %%
data4
data4 = data4.set_index(['index'])

# %%
# data = pd.concat([train, test], axis=0)
# data=data.set_index(['index'])
condition_zero = (data['배합_염료2_Yellow_prop'] == 0.0) & (data['배합_염료2_Blue_prop'] == 0.0) & (data['배합_염료2_Red_prop'] == 0.0)
data = data[~condition_zero]

# 하나라도 1.0인 행 제거
condition_one = (data['배합_염료2_Yellow_prop'] == 1.0) | (data['배합_염료2_Blue_prop'] == 1.0) | (data['배합_염료2_Red_prop'] == 1.0)
data = data[~condition_one]
data
# Out:
#        Unnamed: 0 소재_경사정보_V1  소재_경사정보_V2  소재_경사정보_V3 소재_경사정보_V4
# index
# 718           718  PET 재생 섬유         300          96  Semi Dull  \
# 798           798  PET 재생 섬유         300          96  Semi Dull
# 263           263  PET 재생 섬유         300          96  Semi Dull
# 795           795  PET 재생 섬유         300          96  Semi Dull
# 289           289  PET 재생 섬유         300          96  Semi Dull
# ...           ...        ...         ...         ...        ...
# 770           770  PET 재생 섬유         300          96  Semi Dull
# 248           248  PET 재생 섬유         300          96  Semi Dull
# 777           777  PET 재생 섬유         300          96  Semi Dull
# 778           778  PET 재생 섬유         300          96  Semi Dull
# 727           727  PET 재생 섬유         300          96  Semi Dull
#
#                소재_경사정보_V5  소재_경사정보_V6 소재_경사정보_V7  소재_경사정보_V8  소재_경사정보_V9  ...
# index                                                                     ...
# 718    Draw Textured Yarn          88  Filaments         150         150  ...  \
# 798    Draw Textured Yarn          88  Filaments         150         150  ...
# 263    Draw Textured Yarn          88  Filaments         150         150  ...
# 795    Draw Textured Yarn          88  Filaments         150         150  ...
# 289    Draw Textured Yarn          88  Filaments         150         150  ...
# ...                   ...         ...        ...         ...         ...  ...
# 770    Draw Textured Yarn          88  Filaments         150         150  ...
# 248    Draw Textured Yarn          88  Filaments         150         150  ...
# 777    Draw Textured Yarn          88  Filaments         150         150  ...
# 778    Draw Textured Yarn          88  Filaments         150         150  ...
# 727    Draw Textured Yarn          88  Filaments         150         150  ...
#
#        배합_염료3_Black_prop  배합_염료1_Grey_prop  배합_염료2_Grey_prop
# index
# 718                    0                 0                 0  \
# 798                    0                 0                 0
# 263                    0                 0                 0
# 795                    0                 0                 0
# 289                    0                 0                 0
# ...                  ...               ...               ...
# 770                    0                 0                 0
# 248                    0                 0                 0
# 777                    0                 0                 0
# 778                    0                 0                 0
# 727                    0                 0                 0
#
#        배합_염료3_Grey_prop  배합_염료2_Brown_prop  배합_염료1_Brown_prop
# index
# 718                   0                  0                  0  \
# 798                   0                  0                  0
# 263                   0                  0                  0
# 795                   0                  0                  0
# 289                   0                  0                  0
# ...                 ...                ...                ...
# 770                   0                  0                  0
# 248                   0                  0                  0
# 777                   0                  0                  0
# 778                   0                  0                  0
# 727                   0                  0                  0
#
#       배합_염료3_Brown_prop   색상_L*   색상_a*   색상_b*
# index
# 718                   0  65.475   9.115 -14.155
# 798                   0  45.470 -18.665  14.205
# 263                   0  68.210  37.740   3.600
# 795                   0  51.590  50.310  27.560
# 289                   0  46.330  53.490  31.370
# ...                 ...     ...     ...     ...
# 770                   0  74.820  25.905  12.155
# 248                   0  24.300  10.660 -19.040
# 777                   0  61.715  41.280  19.310
# 778                   0  40.605  16.845  -6.250
# 727                   0  63.950  22.130 -10.345
#
# [112 rows x 174 columns]

# %%
import numpy as np

# 세 열 모두에서 값이 0.333333과 근사적으로 같은 행 필터링
filtered_data2 = data[
    np.isclose(data["배합_염료2_Blue_prop"], 0.333333, atol=1e-6) &
    np.isclose(data["배합_염료2_Yellow_prop"], 0.333333, atol=1e-6) &
    np.isclose(data["배합_염료2_Red_prop"], 0.333333, atol=1e-6)
]

# 필터링된 데이터 출력
filtered_data2.iloc[:,39:100]
filtered_data2.shape
# Out:
# (16, 174)

# %%
dix_test2 = filtered_data2.iloc[:, -3:]

# %%
# dix_test의 인덱스를 열로 변환
dix_test['index'] = dix_test2.index

# RGB 데이터프레임 생성
rgb_list = []
for index, row in dix_test.iterrows():
    R, G, B = lab2rgb(row["색상_L*"], row["색상_a*"], row["색상_b*"])
    rgb_list.append([R, G, B])

rgb_df_test = pd.DataFrame(rgb_list, index=dix_test2.index, columns=["R", "G", "B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_test = pd.concat([dix_test2, rgb_df_test], axis=1)

# 결과 출력
df_rgb_test
# Out:
#         색상_L*   색상_a*  색상_b*           R           G           B
# index
# 796    26.510  14.465 -5.430   80.687719   54.957013   71.229437
# 790    28.865  15.330 -5.700   87.400332   59.722043   77.128505
# 269    45.890  15.760 -6.430  130.195737   99.807549  119.726335
# 754    74.510   9.855 -1.570  200.506529  177.372717  186.431558
# 283    27.990  13.660 -5.740   82.894787   58.828100   75.102035
# 278    31.060  14.800 -6.140   91.693732   65.116687   82.948124
# 759    68.465  11.935 -3.455  186.099477  159.939370  173.478198
# 262    66.760  12.310 -5.150  180.786620  155.302991  171.908926
# 801    23.345  12.390 -4.715   70.770629   49.203569   62.886539
# 787    31.780  15.780 -5.960   94.986687   66.114824   84.404932
# 810    21.030   7.465 -4.160   58.888215   47.009107   56.759503
# 773    50.010  15.775 -6.015  141.226469  109.976693  129.504084
# 782    35.530  16.205 -6.185  104.741490   74.578891   93.749031
# 274    36.820  15.830 -6.340  107.304048   77.879720   97.109495
# 257    71.240   8.180 -6.360  184.495566  169.971139  186.093407
# 778    40.605  16.845 -6.250  118.449242   86.219899  106.271874

# %%
data4["배합_염료2_Red_prop"].value_counts()
# Out:
# 배합_염료2_Red_prop
# 0.000000    3552
# 1.000000      87
# 0.333333      24
# 0.666667       8
# 0.670000       4
# 0.333500       4
# 0.666000       4
# 0.334000       4
# 0.330000       4
# 0.333000       4
# 0.666500       4
# 0.660000       4
# 0.340000       4
# 0.667000       4
# 0.666750       2
# 0.333250       2
# 0.333200       2
# 0.666800       2
# Name: count, dtype: int64

# %%
import numpy as np

# 세 열 모두에서 값이 0.333333과 근사적으로 같은 행 필터링
filtered_data = data4[
    np.isclose(data4["배합_염료2_Blue_prop"], 0.333333, atol=1e-6) &
    np.isclose(data4["배합_염료2_Yellow_prop"], 0.333333, atol=1e-6) &
    np.isclose(data4["배합_염료2_Red_prop"], 0.333333, atol=1e-6)
]

# 필터링된 데이터 출력
filtered_data.iloc[:,39:100]
filtered_data.shape
# Out:
# (16, 174)

# %%
dix_test = filtered_data.iloc[:, -3:]

# %%
# dix_test의 인덱스를 열로 변환
dix_test['index'] = dix_test.index

# RGB 데이터프레임 생성
rgb_list = []
for index, row in dix_test.iterrows():
    R, G, B = lab2rgb(row["색상_L*"], row["색상_a*"], row["색상_b*"])
    rgb_list.append([R, G, B])

rgb_df_test = pd.DataFrame(rgb_list, index=dix_test.index, columns=["R", "G", "B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_test = pd.concat([dix_test, rgb_df_test], axis=1)

# 결과 출력
df_rgb_test
# Out:
#         색상_L*   색상_a*  색상_b*  index           R           G           B
# index
# 796    26.510  14.465 -5.430    796   80.687719   54.957013   71.229437
# 790    28.865  15.330 -5.700    790   87.400332   59.722043   77.128505
# 269    45.890  15.760 -6.430    269  130.195737   99.807549  119.726335
# 754    74.510   9.855 -1.570    754  200.506529  177.372717  186.431558
# 283    27.990  13.660 -5.740    283   82.894787   58.828100   75.102035
# 278    31.060  14.800 -6.140    278   91.693732   65.116687   82.948124
# 759    68.465  11.935 -3.455    759  186.099477  159.939370  173.478198
# 262    66.760  12.310 -5.150    262  180.786620  155.302991  171.908926
# 801    23.345  12.390 -4.715    801   70.770629   49.203569   62.886539
# 787    31.780  15.780 -5.960    787   94.986687   66.114824   84.404932
# 810    21.030   7.465 -4.160    810   58.888215   47.009107   56.759503
# 773    50.010  15.775 -6.015    773  141.226469  109.976693  129.504084
# 782    35.530  16.205 -6.185    782  104.741490   74.578891   93.749031
# 274    36.820  15.830 -6.340    274  107.304048   77.879720   97.109495
# 257    71.240   8.180 -6.360    257  184.495566  169.971139  186.093407
# 778    40.605  16.845 -6.250    778  118.449242   86.219899  106.271874

# %%
import matplotlib.pyplot as plt
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_test[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 단일염료 후처리_NaOH_std': 2.0

# %%
dix_black= data4[data4["Dianix Black AM-SLR_std"] != 0]
dix_black["Dianix Black AM-SLR_std"].value_counts()
# Out:
# Dianix Black AM-SLR_std
# 2.00    25
# 6.00    25
# 0.05    18
# 4.00     8
# 1.00     7
# 3.00     3
# 5.00     3
# 0.10     1
# 2.50     1
# 0.50     1
# 1.50     1
# Name: count, dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_black[column].value_counts() for column in dix_black.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {'위사_소재명_enc': 88,
#  '경사_성상_비율 #3_std': 81,
#  'Dorosperse Yellow KKL_std': 0.0,
#  'Dorosperse Red KKL_std': 0.0,
#  'Dorosperse Blue KKL_std': 0.0,
#  'Dianix Yellow AM-2R_std': 0.0,
#  'Dianix Red AM-SLR_std': 0.0,
#  'Dianix Blue AM-2G_std': 0.0,
#  'Synolon Yellow AK_std': 0.0,
#  'Synolon Red AK_std': 0.0,
#  'Synolon Blue AK_std': 0.0,
#  'Dorosperse B/K KKL_std': 0.0,
#  'Synolon Black AK-NB_std': 0.0,
#  'Dorosperse Dark Grey KKL_std': 0.0,
#  'Dianix Grey AM-SLR_std': 0.0,
#  'Synolon Dark Grey AK_std': 0.0,
#  'Dianix Yellow Brown AM-R_std': 0.0,
#  'Dorosperse Brown K-3LR_std': 0.0,
#  'Synofast 28_std': 0.0,
#  '배합_Sunsolt RM-340S_std': 0.3,
#  '후처리_NaOH_std': 2.0,
#  'Dorosperse Yellow KKL_prop_std': 0.0,
#  'Dorosperse Red KKL_prop_std': 0.0,
#  'Dorosperse Blue KKL_prop_std': 0.0,
#  'Dianix Yellow AM-2R_prop_std': 0.0,
#  'Dianix Red AM-SLR_prop_std': 0.0,
#  'Dianix Blue AM-2G_prop_std': 0.0,
#  'Synolon Yellow AK_prop_std': 0.0,
#  'Synolon Red AK_prop_std': 0.0,
#  'Synolon Blue AK_prop_std': 0.0,
#  'Dorosperse B/K KKL_prop_std': 0,
#  'Dianix Black AM-SLR_prop_std': 1,
#  'Synolon Black AK-NB_prop_std': 0,
#  'Dorosperse Dark Grey KKL_prop_std': 0,
#  'Dianix Grey AM-SLR_prop_std': 0,
#  'Synolon Dark Grey AK_prop_std': 0,
#  'Dianix Yellow Brown AM-R_prop_std': 0,
#  'Dorosperse Brown K-3LR_prop_std': 0,
#  'Synofast 28_prop_std': 0}

# %%
dix_YB= data4[data4["Dianix Yellow Brown AM-R_std"] != 0]
dix_YB["Dianix Yellow Brown AM-R_std"].value_counts()
# Out:
# Dianix Yellow Brown AM-R_std
# 2.00    25
# 6.00    23
# 0.05    18
# 1.00     7
# 4.00     5
# 0.50     3
# 1.50     3
# 2.50     3
# 3.00     3
# 0.10     1
# 5.00     1
# Name: count, dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_YB[column].value_counts() for column in dix_YB.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {'위사_소재명_enc': 88,
#  '경사_성상_비율 #3_std': 81,
#  'Dorosperse Yellow KKL_std': 0.0,
#  'Dorosperse Red KKL_std': 0.0,
#  'Dorosperse Blue KKL_std': 0.0,
#  'Dianix Yellow AM-2R_std': 0.0,
#  'Dianix Red AM-SLR_std': 0.0,
#  'Dianix Blue AM-2G_std': 0.0,
#  'Synolon Yellow AK_std': 0.0,
#  'Synolon Red AK_std': 0.0,
#  'Synolon Blue AK_std': 0.0,
#  'Dorosperse B/K KKL_std': 0.0,
#  'Dianix Black AM-SLR_std': 0.0,
#  'Synolon Black AK-NB_std': 0.0,
#  'Dorosperse Dark Grey KKL_std': 0.0,
#  'Dianix Grey AM-SLR_std': 0.0,
#  'Synolon Dark Grey AK_std': 0.0,
#  'Dorosperse Brown K-3LR_std': 0.0,
#  'Synofast 28_std': 0.0,
#  '배합_Sunsolt RM-340S_std': 0.3,
#  '후처리_NaOH_std': 2.0,
#  'Dorosperse Yellow KKL_prop_std': 0.0,
#  'Dorosperse Red KKL_prop_std': 0.0,
#  'Dorosperse Blue KKL_prop_std': 0.0,
#  'Dianix Yellow AM-2R_prop_std': 0.0,
#  'Dianix Red AM-SLR_prop_std': 0.0,
#  'Dianix Blue AM-2G_prop_std': 0.0,
#  'Synolon Yellow AK_prop_std': 0.0,
#  'Synolon Red AK_prop_std': 0.0,
#  'Synolon Blue AK_prop_std': 0.0,
#  'Dorosperse B/K KKL_prop_std': 0,
#  'Dianix Black AM-SLR_prop_std': 0,
#  'Synolon Black AK-NB_prop_std': 0,
#  'Dorosperse Dark Grey KKL_prop_std': 0,
#  'Dianix Grey AM-SLR_prop_std': 0,
#  'Synolon Dark Grey AK_prop_std': 0,
#  'Dianix Yellow Brown AM-R_prop_std': 1,
#  'Dorosperse Brown K-3LR_prop_std': 0,
#  'Synofast 28_prop_std': 0}

# %%
dix_Gray= data4[data4["Dianix Grey AM-SLR_std"] != 0]
dix_Gray["Dianix Grey AM-SLR_std"].value_counts()
# Out:
# Dianix Grey AM-SLR_std
# 6.00    27
# 2.00    25
# 0.05    18
# 4.00     8
# 1.00     7
# 3.00     3
# 5.00     3
# 0.10     1
# 0.50     1
# 2.50     1
# 1.50     1
# Name: count, dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_Gray[column].value_counts() for column in dix_Gray.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {'위사_소재명_enc': 88,
#  '경사_성상_비율 #3_std': 81,
#  'Dorosperse Yellow KKL_std': 0.0,
#  'Dorosperse Red KKL_std': 0.0,
#  'Dorosperse Blue KKL_std': 0.0,
#  'Dianix Yellow AM-2R_std': 0.0,
#  'Dianix Red AM-SLR_std': 0.0,
#  'Dianix Blue AM-2G_std': 0.0,
#  'Synolon Yellow AK_std': 0.0,
#  'Synolon Red AK_std': 0.0,
#  'Synolon Blue AK_std': 0.0,
#  'Dorosperse B/K KKL_std': 0.0,
#  'Dianix Black AM-SLR_std': 0.0,
#  'Synolon Black AK-NB_std': 0.0,
#  'Dorosperse Dark Grey KKL_std': 0.0,
#  'Synolon Dark Grey AK_std': 0.0,
#  'Dianix Yellow Brown AM-R_std': 0.0,
#  'Dorosperse Brown K-3LR_std': 0.0,
#  'Synofast 28_std': 0.0,
#  '배합_Sunsolt RM-340S_std': 0.3,
#  '후처리_NaOH_std': 2.0,
#  'Dorosperse Yellow KKL_prop_std': 0.0,
#  'Dorosperse Red KKL_prop_std': 0.0,
#  'Dorosperse Blue KKL_prop_std': 0.0,
#  'Dianix Yellow AM-2R_prop_std': 0.0,
#  'Dianix Red AM-SLR_prop_std': 0.0,
#  'Dianix Blue AM-2G_prop_std': 0.0,
#  'Synolon Yellow AK_prop_std': 0.0,
#  'Synolon Red AK_prop_std': 0.0,
#  'Synolon Blue AK_prop_std': 0.0,
#  'Dorosperse B/K KKL_prop_std': 0,
#  'Dianix Black AM-SLR_prop_std': 0,
#  'Synolon Black AK-NB_prop_std': 0,
#  'Dorosperse Dark Grey KKL_prop_std': 0,
#  'Dianix Grey AM-SLR_prop_std': 1,
#  'Synolon Dark Grey AK_prop_std': 0,
#  'Dianix Yellow Brown AM-R_prop_std': 0,
#  'Dorosperse Brown K-3LR_prop_std': 0,
#  'Synofast 28_prop_std': 0}

# %%
dix_yellow= data4[data4["Dianix Yellow AM-2R_std"] != 0]
dix_yellow["Dianix Yellow AM-2R_std"].value_counts()
# Out:
# Dianix Yellow AM-2R_std
# 2.000    29
# 6.000    23
# 0.050    18
# 1.000    13
# 0.033    10
# 0.333    10
# 0.667    10
# 0.500     8
# 4.000     7
# 1.333     7
# 0.167     6
# 0.017     6
# 0.067     4
# 0.833     3
# 1.500     2
# 0.100     2
# 2.500     2
# 3.000     2
# 1.667     2
# 2.667     2
# Name: count, dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_yellow[column].value_counts() for column in dix_yellow.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {'위사_소재명_enc': 88,
#  '경사_성상_비율 #3_std': 81,
#  'Dorosperse Yellow KKL_std': 0.0,
#  'Dorosperse Red KKL_std': 0.0,
#  'Dorosperse Blue KKL_std': 0.0,
#  'Synolon Yellow AK_std': 0.0,
#  'Synolon Red AK_std': 0.0,
#  'Synolon Blue AK_std': 0.0,
#  'Dorosperse B/K KKL_std': 0.0,
#  'Dianix Black AM-SLR_std': 0.0,
#  'Synolon Black AK-NB_std': 0.0,
#  'Dorosperse Dark Grey KKL_std': 0.0,
#  'Dianix Grey AM-SLR_std': 0.0,
#  'Synolon Dark Grey AK_std': 0.0,
#  'Dianix Yellow Brown AM-R_std': 0.0,
#  'Dorosperse Brown K-3LR_std': 0.0,
#  'Synofast 28_std': 0.0,
#  '배합_Sunsolt RM-340S_std': 0.3,
#  '배합_UVK-200_std': 0,
#  '배합_Fadex® TS liq_std': 0.0,
#  '배합_Sera Fast P-UVC_std': 0,
#  'Lab 염색 하강속도 #1_std': 1.97222,
#  'Dorosperse Yellow KKL_prop_std': 0.0,
#  'Dorosperse Red KKL_prop_std': 0.0,
#  'Dorosperse Blue KKL_prop_std': 0.0,
#  'Synolon Yellow AK_prop_std': 0.0,
#  'Synolon Red AK_prop_std': 0.0,
#  'Synolon Blue AK_prop_std': 0.0,
#  'Dorosperse B/K KKL_prop_std': 0,
#  'Dianix Black AM-SLR_prop_std': 0,
#  'Synolon Black AK-NB_prop_std': 0,
#  'Dorosperse Dark Grey KKL_prop_std': 0,
#  'Dianix Grey AM-SLR_prop_std': 0,
#  'Synolon Dark Grey AK_prop_std': 0,
#  'Dianix Yellow Brown AM-R_prop_std': 0,
#  'Dorosperse Brown K-3LR_prop_std': 0,
#  'Synofast 28_prop_std': 0}

# %%
dix_Blue= data4[data4["Dianix Blue AM-2G_std"] != 0]
dix_Blue["Dianix Blue AM-2G_std"].value_counts()
# Out:
# Dianix Blue AM-2G_std
# 2.000    29
# 6.000    23
# 0.050    18
# 1.000    13
# 0.033    10
# 0.667    10
# 0.333    10
# 0.500     8
# 1.333     7
# 4.000     7
# 0.017     6
# 0.167     6
# 0.067     4
# 0.833     3
# 3.000     2
# 2.500     2
# 0.100     2
# 1.500     2
# 1.667     2
# 2.667     2
# Name: count, dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_red[column].value_counts() for column in dix_red.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {}

# %%
dix_red= data4[data4["Dianix Red AM-SLR_std"] != 0]
dix_red["Dianix Red AM-SLR_std"].value_counts()
# Out:
# Dianix Red AM-SLR_std
# 2.000    29
# 6.000    23
# 0.050    19
# 1.000    13
# 0.033    10
# 0.333    10
# 0.667    10
# 0.500     8
# 4.000     7
# 1.333     7
# 0.167     6
# 0.017     6
# 0.067     4
# 0.833     3
# 1.500     2
# 2.500     2
# 3.000     2
# 1.667     2
# 0.100     2
# 2.667     2
# Name: count, dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_red[column].value_counts() for column in dix_red.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {'위사_소재명_enc': 88,
#  '경사_성상_비율 #3_std': 81,
#  'Dorosperse Yellow KKL_std': 0.0,
#  'Dorosperse Red KKL_std': 0.0,
#  'Dorosperse Blue KKL_std': 0.0,
#  'Synolon Yellow AK_std': 0.0,
#  'Synolon Red AK_std': 0.0,
#  'Synolon Blue AK_std': 0.0,
#  'Dorosperse B/K KKL_std': 0.0,
#  'Dianix Black AM-SLR_std': 0.0,
#  'Synolon Black AK-NB_std': 0.0,
#  'Dorosperse Dark Grey KKL_std': 0.0,
#  'Dianix Grey AM-SLR_std': 0.0,
#  'Synolon Dark Grey AK_std': 0.0,
#  'Dianix Yellow Brown AM-R_std': 0.0,
#  'Dorosperse Brown K-3LR_std': 0.0,
#  'Synofast 28_std': 0.0,
#  '배합_Sunsolt RM-340S_std': 0.3,
#  '배합_UVK-200_std': 0,
#  '배합_Fadex® TS liq_std': 0.0,
#  '배합_Sera Fast P-UVC_std': 0,
#  'Lab 염색 하강속도 #1_std': 1.97222,
#  'Dorosperse Yellow KKL_prop_std': 0.0,
#  'Dorosperse Red KKL_prop_std': 0.0,
#  'Dorosperse Blue KKL_prop_std': 0.0,
#  'Synolon Yellow AK_prop_std': 0.0,
#  'Synolon Red AK_prop_std': 0.0,
#  'Synolon Blue AK_prop_std': 0.0,
#  'Dorosperse B/K KKL_prop_std': 0,
#  'Dianix Black AM-SLR_prop_std': 0,
#  'Synolon Black AK-NB_prop_std': 0,
#  'Dorosperse Dark Grey KKL_prop_std': 0,
#  'Dianix Grey AM-SLR_prop_std': 0,
#  'Synolon Dark Grey AK_prop_std': 0,
#  'Dianix Yellow Brown AM-R_prop_std': 0,
#  'Dorosperse Brown K-3LR_prop_std': 0,
#  'Synofast 28_prop_std': 0}

# %% [markdown]
# # R  G B 는 'Lab 염색 하강속도 #1_std': 1.97222

# %% [markdown]
# ## 다이닉스는 Y B R도 단일염료를 사용한다

# %%
dix_yellow2=data4[data4["Dianix Yellow AM-2R_std"] >= 6.0]
dix_yellow2.nunique()
dix_yellow2.iloc[:,0:10]
dix_yellow2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 1397                              0                                  0  \
# 1398                              0                                  0
# 1399                              0                                  0
# 1400                              0                                  0
# 1401                              0                                  0
# 1402                              0                                  0
# 1403                              0                                  0
# 1404                              0                                  0
# 1405                              0                                  0
# 1406                              0                                  0
# 1407                              0                                  0
# 1408                              0                                  0
# 1409                              0                                  0
# 1410                              0                                  0
# 1411                              0                                  0
# 1412                              0                                  0
# 1413                              0                                  0
# 1414                              0                                  0
# 1415                              0                                  0
# 1416                              0                                  0
# 1417                              0                                  0
# 3436                              0                                  0
# 3517                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std   색상_L*    색상_a*
# 1397                                0                     0  73.200  25.5950  \
# 1398                                0                     0  73.050  25.4300
# 1399                                0                     0  73.175  25.6650
# 1400                                0                     0  73.190  25.9100
# 1401                                0                     0  73.055  25.5400
# 1402                                0                     0  73.230  25.7600
# 1403                                0                     0  90.975  -1.2650
# 1404                                0                     0  78.390  13.8350
# 1405                                0                     0  77.170  19.7450
# 1406                                0                     0  75.455  22.9800
# 1407                                0                     0  74.295  24.7600
# 1408                                0                     0  73.580  25.8800
# 1409                                0                     0  73.370  26.1600
# 1410                                0                     0  72.855  25.5125
# 1411                                0                     0  73.230  25.9700
# 1412                                0                     0  73.075  25.7700
# 1413                                0                     0  72.300  24.9550
# 1414                                0                     0  73.080  25.6150
# 1415                                0                     0  72.810  25.4100
# 1416                                0                     0  72.665  25.3750
# 1417                                0                     0  72.765  26.3300
# 3436                                0                     0  72.860  26.3050
# 3517                                0                     0  72.825  25.2750
#
#         색상_b*
# 1397  87.3250
# 1398  86.8650
# 1399  87.2950
# 1400  87.4900
# 1401  87.1100
# 1402  87.4350
# 1403  25.0600
# 1404  75.7300
# 1405  84.3950
# 1406  86.3950
# 1407  87.1500
# 1408  87.5900
# 1409  87.6800
# 1410  86.2750
# 1411  87.5200
# 1412  87.3850
# 1413  86.1350
# 1414  87.1300
# 1415  86.8600
# 1416  86.1675
# 1417  86.7250
# 3436  87.5000
# 3517  86.5650

# %%
dix_yellow2.iloc[:,28:40]
# 1403 이상한값이라고 생각되는값이 170 0.83333 120 단일염색에서 같은 수치를 보이고잇아
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 1397                 0.5                0.50            0.500000  \
# 1398                 0.5                0.50            1.500000
# 1399                 0.5                1.50            0.500000
# 1400                 0.5                1.50            1.500000
# 1401                 1.5                0.50            0.500000
# 1402                 1.5                0.50            1.500000
# 1403                 1.5                0.75            0.833333
# 1404                 1.5                0.75            1.250000
# 1405                 1.5                0.75            1.458333
# 1406                 1.5                0.75            1.458333
# 1407                 1.5                0.75            1.458333
# 1408                 1.5                0.75            1.458333
# 1409                 1.5                0.75            1.458333
# 1410                 1.5                0.75            1.458333
# 1411                 1.5                0.75            1.458333
# 1412                 1.5                0.75            1.458333
# 1413                 1.5                0.75            1.666667
# 1414                 1.5                1.50            0.500000
# 1415                 1.5                1.50            1.500000
# 1416                 1.5                0.75            1.458333
# 1417                 1.5                0.75            1.458333
# 3436                 1.5                0.75            1.458333
# 3517                 1.5                0.75            1.458333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 1397                 135                       60             1.97222  \
# 1398                 135                       60             1.97222
# 1399                 135                       60             1.97222
# 1400                 135                       60             1.97222
# 1401                 135                       60             1.97222
# 1402                 135                       60             1.97222
# 1403                 120                       60             1.97222
# 1404                 130                       60             1.97222
# 1405                 135                       10             1.97222
# 1406                 135                       20             1.97222
# 1407                 135                       30             1.97222
# 1408                 135                       40             1.97222
# 1409                 135                       50             1.97222
# 1410                 135                       60             1.97222
# 1411                 135                       70             1.97222
# 1412                 135                       80             1.97222
# 1413                 140                       60             1.97222
# 1414                 135                       60             1.97222
# 1415                 135                       60             1.97222
# 1416                 135                       60             1.97222
# 1417                 135                       60             1.97222
# 3436                 135                       60             1.97222
# 3517                 135                       60             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 1397           2.0                     4.0                             0.0  \
# 1398           2.0                     4.0                             0.0
# 1399           2.0                     4.0                             0.0
# 1400           2.0                     4.0                             0.0
# 1401           2.0                     4.0                             0.0
# 1402           2.0                     4.0                             0.0
# 1403           2.0                     4.0                             0.0
# 1404           2.0                     4.0                             0.0
# 1405           2.0                     4.0                             0.0
# 1406           2.0                     4.0                             0.0
# 1407           2.0                     4.0                             0.0
# 1408           2.0                     4.0                             0.0
# 1409           2.0                     4.0                             0.0
# 1410           2.0                     4.0                             0.0
# 1411           2.0                     4.0                             0.0
# 1412           2.0                     4.0                             0.0
# 1413           2.0                     4.0                             0.0
# 1414           2.0                     4.0                             0.0
# 1415           2.0                     4.0                             0.0
# 1416           2.0                     4.0                             0.0
# 1417           2.0                     4.0                             0.0
# 3436           2.0                     4.0                             0.0
# 3517           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  Dorosperse Blue KKL_prop_std
# 1397                          0.0                           0.0  \
# 1398                          0.0                           0.0
# 1399                          0.0                           0.0
# 1400                          0.0                           0.0
# 1401                          0.0                           0.0
# 1402                          0.0                           0.0
# 1403                          0.0                           0.0
# 1404                          0.0                           0.0
# 1405                          0.0                           0.0
# 1406                          0.0                           0.0
# 1407                          0.0                           0.0
# 1408                          0.0                           0.0
# 1409                          0.0                           0.0
# 1410                          0.0                           0.0
# 1411                          0.0                           0.0
# 1412                          0.0                           0.0
# 1413                          0.0                           0.0
# 1414                          0.0                           0.0
# 1415                          0.0                           0.0
# 1416                          0.0                           0.0
# 1417                          0.0                           0.0
# 3436                          0.0                           0.0
# 3517                          0.0                           0.0
#
#       Dianix Yellow AM-2R_prop_std
# 1397                           1.0
# 1398                           1.0
# 1399                           1.0
# 1400                           1.0
# 1401                           1.0
# 1402                           1.0
# 1403                           1.0
# 1404                           1.0
# 1405                           1.0
# 1406                           1.0
# 1407                           1.0
# 1408                           1.0
# 1409                           1.0
# 1410                           1.0
# 1411                           1.0
# 1412                           1.0
# 1413                           1.0
# 1414                           1.0
# 1415                           1.0
# 1416                           1.0
# 1417                           1.0
# 3436                           1.0
# 3517                           1.0

# %% [markdown]
# #### 수치 6이 무조건 단일렴료이고 2~5.9 사이에는 종종 합성연료가보인다

# %%
dix_Blue2=data4[data4["Dianix Blue AM-2G_std"] >= 6.0]
dix_Blue2.nunique()
dix_Blue2.iloc[:,0:10]
dix_Blue2.iloc[:,50:60]
dix_Blue2.to_csv("/Users/b32/Desktop/ㅇㅇㅇㅇㅇㅇ/bluesample.csv")

# %%
import math

def lab2rgb(l_s, a_s, b_s):
    var_Y = (l_s + 16) / 116.0
    var_X = a_s / 500.0 + var_Y
    var_Z = var_Y - b_s / 200.0

    if var_Y**3 > 0.008856:
        var_Y = var_Y**3
    else:
        var_Y = (var_Y - 16/116) / 7.787
    if var_X**3 > 0.008856:
        var_X = var_X**3
    else:
        var_X = (var_X - 16/116) / 7.787
    if var_Z**3 > 0.008856:
        var_Z = var_Z**3
    else:
        var_Z = (var_Z - 16/116) / 7.787

    X = 95.047 * var_X
    Y = 100.000 * var_Y
    Z = 108.883 * var_Z

    var_X = X / 100.0
    var_Y = Y / 100.0
    var_Z = Z / 100.0

    var_R = var_X * 3.2406 + var_Y * -1.5372 + var_Z * -0.4986
    var_G = var_X * -0.9689 + var_Y * 1.8758 + var_Z * 0.0415
    var_B = var_X * 0.0557 + var_Y * -0.2040 + var_Z * 1.0570

    if var_R > 0.0031308:
        var_R = 1.055 * (var_R ** (1/2.4)) - 0.055
    else:
        var_R = 12.92 * var_R
    if var_G > 0.0031308:
        var_G = 1.055 * (var_G ** (1/2.4)) - 0.055
    else:
        var_G = 12.92 * var_G
    if var_B > 0.0031308:
        var_B = 1.055 * (var_B ** (1/2.4)) - 0.055
    else:
        var_B = 12.92 * var_B

    R = var_R * 255.0
    G = var_G * 255.0
    B = var_B * 255.0

    return R, G, B

# 이 함수는 주어진 L*a*b* 값을 RGB 값으로 변환합니다.
# 예를 들어:
R, G, B = lab2rgb(25.42, 8.9475, -22.77125)
print(R, G, B)
# Out:
# 53.07723315495199 57.46896050808887 94.70754149923732

# %%
dix_Blue3 = dix_Blue2.iloc[:, -3:]
dix_yellow3 = dix_yellow2.iloc[:, -3:]
dix_red3 = dix_red2.iloc[:, -3:]

# %%
rgb_list=[]
for index, row in dix_red3.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_red3.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb = pd.concat([dix_red3, rgb_df], axis=1,)

# %% [markdown]
# ###  단일값 가져오는 코드 인덱스 별로 사용하시면됩니다
# - 사용법은 저가 선언한 코드만 수정해주세요
# - df_rgb를 색상을 다르게선언하면됩니다

# %%
import matplotlib.pyplot as plt
import numpy as np  # numpy 임포트 추가

def plot_rgb_color(df, row_index):
    # 해당 위치의 RGB 값을 가져옵니다. iloc를 사용하여 위치 기반으로 접근합니다.
    color = df.iloc[row_index][['R', 'G', 'B']].values
    # RGB 값이 0에서 255 범위에 있는지 확인하고, 그렇지 않다면 정규화합니다.
    color = color / 255 if np.any(color > 1) else color
    
    # 색상을 시각화합니다.
    plt.figure(figsize=(2, 2))
    plt.imshow([[(color[0], color[1], color[2])]])  # RGB 값으로 채워진 이미지 생성
    plt.axis('off')  # 축을 숨깁니다.
    plt.show()

# 첫 번째 행의 RGB 색상을 시각화합니다.
plot_rgb_color(df_rgb, 3)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()

# %%
rgb_list=[]
for index, row in dix_yellow3.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_yellow3.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb2 = pd.concat([dix_yellow3, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb2[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
rgb_list=[]
for index, row in dix_Blue3.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_Blue3.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb3 = pd.concat([dix_Blue3, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb3[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
dix_red2=data4[data4["Dianix Red AM-SLR_std"] >= 6.0]
dix_red2.nunique()
dix_red2.iloc[:,0:10]
dix_red2.iloc[:,50:60]
dix_red2.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 665                  1.5                0.75            1.458333  \
# 1342                 0.5                0.50            0.500000
# 1343                 0.5                0.50            1.500000
# 1344                 0.5                1.50            0.500000
# 1345                 0.5                1.50            1.500000
# 1346                 1.5                0.50            0.500000
# 1347                 1.5                0.75            0.833333
# 1348                 1.5                0.75            1.250000
# 1349                 1.5                0.75            1.458333
# 1350                 1.5                0.75            1.458333
# 1351                 1.5                0.75            1.458333
# 1352                 1.5                0.75            1.458333
# 1353                 1.5                0.75            1.458333
# 1354                 1.5                0.75            1.458333
# 1355                 1.5                0.75            1.458333
# 1356                 1.5                0.75            1.458333
# 1357                 1.5                0.75            1.666667
# 1358                 1.5                1.50            0.500000
# 1359                 1.5                1.50            1.500000
# 1360                 1.5                0.75            1.458333
# 1361                 1.5                0.75            1.458333
# 3511                 1.5                0.50            1.500000
# 3512                 1.5                0.75            1.458333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 665                  135                       60             1.97222  \
# 1342                 135                       60             1.97222
# 1343                 135                       60             1.97222
# 1344                 135                       60             1.97222
# 1345                 135                       60             1.97222
# 1346                 135                       60             1.97222
# 1347                 120                       60             1.97222
# 1348                 130                       60             1.97222
# 1349                 135                       10             1.97222
# 1350                 135                       20             1.97222
# 1351                 135                       30             1.97222
# 1352                 135                       40             1.97222
# 1353                 135                       50             1.97222
# 1354                 135                       60             1.97222
# 1355                 135                       70             1.97222
# 1356                 135                       80             1.97222
# 1357                 140                       60             1.97222
# 1358                 135                       60             1.97222
# 1359                 135                       60             1.97222
# 1360                 135                       60             1.97222
# 1361                 135                       60             1.97222
# 3511                 135                       60             1.97222
# 3512                 135                       60             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 665            2.0                     4.0                             0.0  \
# 1342           2.0                     4.0                             0.0
# 1343           2.0                     4.0                             0.0
# 1344           2.0                     4.0                             0.0
# 1345           2.0                     4.0                             0.0
# 1346           2.0                     4.0                             0.0
# 1347           2.0                     4.0                             0.0
# 1348           2.0                     4.0                             0.0
# 1349           2.0                     4.0                             0.0
# 1350           2.0                     4.0                             0.0
# 1351           2.0                     4.0                             0.0
# 1352           2.0                     4.0                             0.0
# 1353           2.0                     4.0                             0.0
# 1354           2.0                     4.0                             0.0
# 1355           2.0                     4.0                             0.0
# 1356           2.0                     4.0                             0.0
# 1357           2.0                     4.0                             0.0
# 1358           2.0                     4.0                             0.0
# 1359           2.0                     4.0                             0.0
# 1360           2.0                     4.0                             0.0
# 1361           2.0                     4.0                             0.0
# 3511           2.0                     4.0                             0.0
# 3512           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  Dorosperse Blue KKL_prop_std
# 665                           0.0                           0.0  \
# 1342                          0.0                           0.0
# 1343                          0.0                           0.0
# 1344                          0.0                           0.0
# 1345                          0.0                           0.0
# 1346                          0.0                           0.0
# 1347                          0.0                           0.0
# 1348                          0.0                           0.0
# 1349                          0.0                           0.0
# 1350                          0.0                           0.0
# 1351                          0.0                           0.0
# 1352                          0.0                           0.0
# 1353                          0.0                           0.0
# 1354                          0.0                           0.0
# 1355                          0.0                           0.0
# 1356                          0.0                           0.0
# 1357                          0.0                           0.0
# 1358                          0.0                           0.0
# 1359                          0.0                           0.0
# 1360                          0.0                           0.0
# 1361                          0.0                           0.0
# 3511                          0.0                           0.0
# 3512                          0.0                           0.0
#
#       Dianix Yellow AM-2R_prop_std
# 665                            0.0
# 1342                           0.0
# 1343                           0.0
# 1344                           0.0
# 1345                           0.0
# 1346                           0.0
# 1347                           0.0
# 1348                           0.0
# 1349                           0.0
# 1350                           0.0
# 1351                           0.0
# 1352                           0.0
# 1353                           0.0
# 1354                           0.0
# 1355                           0.0
# 1356                           0.0
# 1357                           0.0
# 1358                           0.0
# 1359                           0.0
# 1360                           0.0
# 1361                           0.0
# 3511                           0.0
# 3512                           0.0

# %% [raw]
# # 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
# df_rgb_normalized = df_rgb[['R', 'G', 'B']] / 255
#
# # 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
# n_rows = len(df_rgb_normalized) // 5 + 1
# n_cols = 5
#
# # 시각화를 위한 준비
# fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.
#
# # axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
# if n_rows == 1:
#     axs = np.array([axs])
#
# # 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
# for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
#     ax = axs[i // n_cols, i % n_cols]
#     ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
#     ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
#     ax.axis('off')  # 축을 숨깁니다.
#
# # 남은 서브플롯을 숨깁니다.
# for j in range(i+1, n_rows*n_cols):
#     axs[j // n_cols, j % n_cols].axis('off')
#
# plt.tight_layout()
# plt.show()

# %%
dix_red2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 665                               0                                  0  \
# 1342                              0                                  0
# 1343                              0                                  0
# 1344                              0                                  0
# 1345                              0                                  0
# 1346                              0                                  0
# 1347                              0                                  0
# 1348                              0                                  0
# 1349                              0                                  0
# 1350                              0                                  0
# 1351                              0                                  0
# 1352                              0                                  0
# 1353                              0                                  0
# 1354                              0                                  0
# 1355                              0                                  0
# 1356                              0                                  0
# 1357                              0                                  0
# 1358                              0                                  0
# 1359                              0                                  0
# 1360                              0                                  0
# 1361                              0                                  0
# 3511                              0                                  0
# 3512                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std    색상_L*    색상_a*
# 665                                 0                     0  36.8500  54.9100  \
# 1342                                0                     0  35.6500  54.1800
# 1343                                0                     0  35.5350  53.9600
# 1344                                0                     0  35.5400  54.1150
# 1345                                0                     0  35.3050  53.8050
# 1346                                0                     0  35.3800  53.8600
# 1347                                0                     0  72.9500  33.7000
# 1348                                0                     0  40.2700  57.4550
# 1349                                0                     0  39.3250  56.3250
# 1350                                0                     0  37.4450  55.4850
# 1351                                0                     0  36.1400  54.5250
# 1352                                0                     0  35.7700  54.3150
# 1353                                0                     0  35.3100  53.7750
# 1354                                0                     0  33.5475  51.9900
# 1355                                0                     0  34.8750  53.2400
# 1356                                0                     0  34.4400  52.7600
# 1357                                0                     0  32.8950  50.9800
# 1358                                0                     0  35.2100  53.7050
# 1359                                0                     0  36.6700  54.9350
# 1360                                0                     0  33.5900  52.1050
# 1361                                0                     0  34.3600  52.9050
# 3511                                0                     0  35.2300  53.6450
# 3512                                0                     0  34.1050  52.6025
#
#        색상_b*
# 665   18.005
# 1342  20.355
# 1343  20.360
# 1344  20.360
# 1345  20.455
# 1346  20.415
# 1347  -1.580
# 1348  15.370
# 1349  15.600
# 1350  17.965
# 1351  19.535
# 1352  19.965
# 1353  20.410
# 1354  21.515
# 1355  20.895
# 1356  21.135
# 1357  21.705
# 1358  20.370
# 1359  18.990
# 1360  21.590
# 1361  21.005
# 3511  20.465
# 3512  21.220

# %%
dix_black2=data4[data4["Dianix Black AM-SLR_std"] >= 2.0]
dix_black2.nunique()
dix_black2.iloc[:,0:10]
dix_black2.iloc[:,50:60]
dix_black2.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 118                  1.5                0.75            1.500000  \
# 119                  1.5                0.75            1.500000
# 120                  1.5                0.75            1.500000
# 121                  1.5                0.75            1.500000
# 122                  1.5                0.75            1.500000
# ...                  ...                 ...                 ...
# 3485                 1.5                0.75            0.833333
# 3486                 1.5                1.50            0.500000
# 3487                 1.5                0.75            1.458333
# 3488                 1.5                0.75            1.458333
# 3489                 1.5                0.75            1.458333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 118                  136                       60             2.00000  \
# 119                  136                       60             2.00000
# 120                  136                       60             2.00000
# 121                  136                       60             2.00000
# 122                  136                       60             2.00000
# ...                  ...                      ...                 ...
# 3485                 120                       60             1.97222
# 3486                 135                       60             1.97222
# 3487                 135                       60             1.97222
# 3488                 135                       10             1.97222
# 3489                 135                       60             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 118            2.0                     2.0                             0.0  \
# 119            2.0                     2.0                             0.0
# 120            2.0                     2.0                             0.0
# 121            2.0                     2.0                             0.0
# 122            2.0                     2.0                             0.0
# ...            ...                     ...                             ...
# 3485           2.0                     4.0                             0.0
# 3486           2.0                     4.0                             0.0
# 3487           2.0                     4.0                             0.0
# 3488           2.0                     4.0                             0.0
# 3489           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  Dorosperse Blue KKL_prop_std
# 118                           0.0                           0.0  \
# 119                           0.0                           0.0
# 120                           0.0                           0.0
# 121                           0.0                           0.0
# 122                           0.0                           0.0
# ...                           ...                           ...
# 3485                          0.0                           0.0
# 3486                          0.0                           0.0
# 3487                          0.0                           0.0
# 3488                          0.0                           0.0
# 3489                          0.0                           0.0
#
#       Dianix Yellow AM-2R_prop_std
# 118                            0.0
# 119                            0.0
# 120                            0.0
# 121                            0.0
# 122                            0.0
# ...                            ...
# 3485                           0.0
# 3486                           0.0
# 3487                           0.0
# 3488                           0.0
# 3489                           0.0
#
# [65 rows x 12 columns]

# %%
#3845
dix_black_speacal=data4[data4["Dianix Black AM-SLR_std"] > 0.0]
dix_black_speacal2=dix_black_speacal[dix_black_speacal["색상_L*"] >= 60.0]

# %%
dix_black_speacal2["Dianix Black AM-SLR_std"].value_counts()
dix_black_speacal2.nunique()
# Out:
# 위사_소재명_enc                            1
# 경사_성상_비율 #3_std                       1
# 제직_중량_생지_std                          2
# 전처리_CH3COOH_std                       1
# Dorosperse Yellow KKL_std             1
# Dorosperse Red KKL_std                1
# Dorosperse Blue KKL_std               1
# Dianix Yellow AM-2R_std               1
# Dianix Red AM-SLR_std                 1
# Dianix Blue AM-2G_std                 1
# Synolon Yellow AK_std                 1
# Synolon Red AK_std                    1
# Synolon Blue AK_std                   1
# Dorosperse B/K KKL_std                1
# Dianix Black AM-SLR_std               3
# Synolon Black AK-NB_std               1
# Dorosperse Dark Grey KKL_std          1
# Dianix Grey AM-SLR_std                1
# Synolon Dark Grey AK_std              1
# Dianix Yellow Brown AM-R_std          1
# Dorosperse Brown K-3LR_std            1
# Synofast 28_std                       1
# 배합_Sunsolt RM-340S_std                1
# 배합_빙초산_std                            1
# 배합_UVK-200_std                        1
# 배합_Fadex® TS liq_std                  1
# 배합_UVK-400 H/C_std                    1
# 배합_Sera Fast P-UVC_std                1
# Lab 염색 상승속도 #1_std                    2
# Lab 염색 상승속도 #2_std                    3
# Lab 염색 상승속도 #3_std                    4
# Lab 염색 상승온도 #3_std                    2
# Lab 염색 상승온도 #3 유지시간_std               8
# Lab 염색 하강속도 #1_std                    1
# 후처리_NaOH_std                          1
# 후처리_Sera Con M-FAS_std                1
# Dorosperse Yellow KKL_prop_std        1
# Dorosperse Red KKL_prop_std           1
# Dorosperse Blue KKL_prop_std          1
# Dianix Yellow AM-2R_prop_std          1
# Dianix Red AM-SLR_prop_std            1
# Dianix Blue AM-2G_prop_std            1
# Synolon Yellow AK_prop_std            1
# Synolon Red AK_prop_std               1
# Synolon Blue AK_prop_std              1
# Dorosperse B/K KKL_prop_std           1
# Dianix Black AM-SLR_prop_std          1
# Synolon Black AK-NB_prop_std          1
# Dorosperse Dark Grey KKL_prop_std     1
# Dianix Grey AM-SLR_prop_std           1
# Synolon Dark Grey AK_prop_std         1
# Dianix Yellow Brown AM-R_prop_std     1
# Dorosperse Brown K-3LR_prop_std       1
# Synofast 28_prop_std                  1
# 색상_L*                                19
# 색상_a*                                18
# 색상_b*                                18
# dtype: int64

# %%
# Let's create a condition to find and list columns with only one unique category in the form "Column Name: Category".

# Calculate the value counts for each column in the dataframe
value_counts_per_column = {column: dix_black_speacal2[column].value_counts() for column in dix_black_speacal2.columns}

# Filter out the columns that have only one unique value
single_value_columns = {column: values for column, values in value_counts_per_column.items() if len(values) == 1}

# Now, format the results as requested: "Column Name: Category"
single_value_columns_formatted = {column: values.index[0] for column, values in single_value_columns.items()}

single_value_columns_formatted
# Out:
# {'위사_소재명_enc': 88,
#  '경사_성상_비율 #3_std': 81,
#  '전처리_CH3COOH_std': 1.0,
#  'Dorosperse Yellow KKL_std': 0.0,
#  'Dorosperse Red KKL_std': 0.0,
#  'Dorosperse Blue KKL_std': 0.0,
#  'Dianix Yellow AM-2R_std': 0.0,
#  'Dianix Red AM-SLR_std': 0.0,
#  'Dianix Blue AM-2G_std': 0.0,
#  'Synolon Yellow AK_std': 0.0,
#  'Synolon Red AK_std': 0.0,
#  'Synolon Blue AK_std': 0.0,
#  'Dorosperse B/K KKL_std': 0.0,
#  'Synolon Black AK-NB_std': 0.0,
#  'Dorosperse Dark Grey KKL_std': 0.0,
#  'Dianix Grey AM-SLR_std': 0.0,
#  'Synolon Dark Grey AK_std': 0.0,
#  'Dianix Yellow Brown AM-R_std': 0.0,
#  'Dorosperse Brown K-3LR_std': 0.0,
#  'Synofast 28_std': 0.0,
#  '배합_Sunsolt RM-340S_std': 0.3,
#  '배합_빙초산_std': 0.2,
#  '배합_UVK-200_std': 0,
#  '배합_Fadex® TS liq_std': 0.0,
#  '배합_UVK-400 H/C_std': 0,
#  '배합_Sera Fast P-UVC_std': 0,
#  'Lab 염색 하강속도 #1_std': 1.97222,
#  '후처리_NaOH_std': 2.0,
#  '후처리_Sera Con M-FAS_std': 4.0,
#  'Dorosperse Yellow KKL_prop_std': 0.0,
#  'Dorosperse Red KKL_prop_std': 0.0,
#  'Dorosperse Blue KKL_prop_std': 0.0,
#  'Dianix Yellow AM-2R_prop_std': 0.0,
#  'Dianix Red AM-SLR_prop_std': 0.0,
#  'Dianix Blue AM-2G_prop_std': 0.0,
#  'Synolon Yellow AK_prop_std': 0.0,
#  'Synolon Red AK_prop_std': 0.0,
#  'Synolon Blue AK_prop_std': 0.0,
#  'Dorosperse B/K KKL_prop_std': 0,
#  'Dianix Black AM-SLR_prop_std': 1,
#  'Synolon Black AK-NB_prop_std': 0,
#  'Dorosperse Dark Grey KKL_prop_std': 0,
#  'Dianix Grey AM-SLR_prop_std': 0,
#  'Synolon Dark Grey AK_prop_std': 0,
#  'Dianix Yellow Brown AM-R_prop_std': 0,
#  'Dorosperse Brown K-3LR_prop_std': 0,
#  'Synofast 28_prop_std': 0}

# %%
dix_black_speacal2.iloc[:,0:10]
dix_black_speacal2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 468                               0                                  0  \
# 469                               0                                  0
# 470                               0                                  0
# 471                               0                                  0
# 472                               0                                  0
# 473                               0                                  0
# 474                               0                                  0
# 475                               0                                  0
# 1145                              0                                  0
# 1146                              0                                  0
# 1147                              0                                  0
# 1148                              0                                  0
# 1149                              0                                  0
# 1151                              0                                  0
# 1152                              0                                  0
# 3403                              0                                  0
# 3482                              0                                  0
# 3483                              0                                  0
# 3485                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std   색상_L*  색상_a*
# 468                                 0                     0  74.225 -0.010  \
# 469                                 0                     0  74.300  0.030
# 470                                 0                     0  74.410  0.160
# 471                                 0                     0  74.295  0.180
# 472                                 0                     0  75.265  0.335
# 473                                 0                     0  74.415  0.165
# 474                                 0                     0  74.395  0.080
# 475                                 0                     0  68.985  0.500
# 1145                                0                     0  74.565  0.210
# 1146                                0                     0  74.250 -0.115
# 1147                                0                     0  74.425 -0.055
# 1148                                0                     0  74.330  0.050
# 1149                                0                     0  74.155  0.100
# 1151                                0                     0  73.835  0.055
# 1152                                0                     0  74.475  0.255
# 3403                                0                     0  74.490  0.075
# 3482                                0                     0  74.370  0.055
# 3483                                0                     0  74.650  0.020
# 3485                                0                     0  74.030  0.185
#
#       색상_b*
# 468   2.770
# 469   2.965
# 470   2.685
# 471   2.685
# 472   1.905
# 473   2.615
# 474   3.075
# 475   2.025
# 1145  2.565
# 1146  3.865
# 1147  4.010
# 1148  3.785
# 1149  1.665
# 1151  2.630
# 1152  2.315
# 3403  2.910
# 3482  3.305
# 3483  3.510
# 3485  2.450

# %%
dix_black_speacal2.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 468                  1.5                0.75            1.458333  \
# 469                  1.5                0.75            1.458333
# 470                  1.5                0.75            1.458333
# 471                  1.5                0.75            1.458333
# 472                  1.5                0.75            1.458333
# 473                  1.5                0.75            1.458333
# 474                  1.5                0.75            1.458333
# 475                  1.5                0.75            1.458333
# 1145                 0.5                0.50            0.500000
# 1146                 0.5                1.50            0.500000
# 1147                 1.5                0.50            0.500000
# 1148                 1.5                0.50            1.500000
# 1149                 1.5                0.75            0.833333
# 1151                 1.5                1.50            0.500000
# 1152                 1.5                1.50            1.500000
# 3403                 1.5                0.75            1.458333
# 3482                 0.5                0.50            1.500000
# 3483                 0.5                1.50            1.500000
# 3485                 1.5                0.75            0.833333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 468                  135                       10             1.97222  \
# 469                  135                       20             1.97222
# 470                  135                       40             1.97222
# 471                  135                       50             1.97222
# 472                  135                       60             1.97222
# 473                  135                       70             1.97222
# 474                  135                       80             1.97222
# 475                  135                       60             1.97222
# 1145                 135                       60             1.97222
# 1146                 135                       60             1.97222
# 1147                 135                       60             1.97222
# 1148                 135                       60             1.97222
# 1149                 120                       60             1.97222
# 1151                 135                       60             1.97222
# 1152                 135                       60             1.97222
# 3403                 135                       30             1.97222
# 3482                 135                       60             1.97222
# 3483                 135                       60             1.97222
# 3485                 120                       60             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 468            2.0                     4.0                             0.0  \
# 469            2.0                     4.0                             0.0
# 470            2.0                     4.0                             0.0
# 471            2.0                     4.0                             0.0
# 472            2.0                     4.0                             0.0
# 473            2.0                     4.0                             0.0
# 474            2.0                     4.0                             0.0
# 475            2.0                     4.0                             0.0
# 1145           2.0                     4.0                             0.0
# 1146           2.0                     4.0                             0.0
# 1147           2.0                     4.0                             0.0
# 1148           2.0                     4.0                             0.0
# 1149           2.0                     4.0                             0.0
# 1151           2.0                     4.0                             0.0
# 1152           2.0                     4.0                             0.0
# 3403           2.0                     4.0                             0.0
# 3482           2.0                     4.0                             0.0
# 3483           2.0                     4.0                             0.0
# 3485           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  Dorosperse Blue KKL_prop_std
# 468                           0.0                           0.0  \
# 469                           0.0                           0.0
# 470                           0.0                           0.0
# 471                           0.0                           0.0
# 472                           0.0                           0.0
# 473                           0.0                           0.0
# 474                           0.0                           0.0
# 475                           0.0                           0.0
# 1145                          0.0                           0.0
# 1146                          0.0                           0.0
# 1147                          0.0                           0.0
# 1148                          0.0                           0.0
# 1149                          0.0                           0.0
# 1151                          0.0                           0.0
# 1152                          0.0                           0.0
# 3403                          0.0                           0.0
# 3482                          0.0                           0.0
# 3483                          0.0                           0.0
# 3485                          0.0                           0.0
#
#       Dianix Yellow AM-2R_prop_std
# 468                            0.0
# 469                            0.0
# 470                            0.0
# 471                            0.0
# 472                            0.0
# 473                            0.0
# 474                            0.0
# 475                            0.0
# 1145                           0.0
# 1146                           0.0
# 1147                           0.0
# 1148                           0.0
# 1149                           0.0
# 1151                           0.0
# 1152                           0.0
# 3403                           0.0
# 3482                           0.0
# 3483                           0.0
# 3485                           0.0

# %%
dix_black_speacal2["Dianix Black AM-SLR_std"].value_counts()
# Out:
# Dianix Black AM-SLR_std
# 0.05    17
# 0.10     1
# 2.00     1
# Name: count, dtype: int64

# %%
rgb_list=[]
for index, row in dix_black_speacal2.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_black_speacal2.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_black = pd.concat([dix_black_speacal2, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_black[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 색상피처 저장

# %%
dix_black3 = dix_black_speacal2.iloc[:, -3:]
dix_YB3= dix_YB2.iloc[:, -3:]
dix_Gray3= dix_Gray2.iloc[:, -3:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 dix_black3 = dix_black_speacal2.iloc[:, -3:]
# ----> 2 dix_YB3= dix_YB2.iloc[:, -3:]
#       3 dix_Gray3= dix_Gray2.iloc[:, -3:]
#
# NameError: name 'dix_YB2' is not defined

# %%
rgb_list=[]
for index, row in dix_black3.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_black3.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_b = pd.concat([dix_black3, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_b[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()

# %%
dix_black_speacal2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 468                               0                                  0  \
# 469                               0                                  0
# 470                               0                                  0
# 471                               0                                  0
# 472                               0                                  0
# 473                               0                                  0
# 474                               0                                  0
# 475                               0                                  0
# 1145                              0                                  0
# 1146                              0                                  0
# 1147                              0                                  0
# 1148                              0                                  0
# 1149                              0                                  0
# 1151                              0                                  0
# 1152                              0                                  0
# 3403                              0                                  0
# 3482                              0                                  0
# 3483                              0                                  0
# 3485                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std   색상_L*  색상_a*
# 468                                 0                     0  74.225 -0.010  \
# 469                                 0                     0  74.300  0.030
# 470                                 0                     0  74.410  0.160
# 471                                 0                     0  74.295  0.180
# 472                                 0                     0  75.265  0.335
# 473                                 0                     0  74.415  0.165
# 474                                 0                     0  74.395  0.080
# 475                                 0                     0  68.985  0.500
# 1145                                0                     0  74.565  0.210
# 1146                                0                     0  74.250 -0.115
# 1147                                0                     0  74.425 -0.055
# 1148                                0                     0  74.330  0.050
# 1149                                0                     0  74.155  0.100
# 1151                                0                     0  73.835  0.055
# 1152                                0                     0  74.475  0.255
# 3403                                0                     0  74.490  0.075
# 3482                                0                     0  74.370  0.055
# 3483                                0                     0  74.650  0.020
# 3485                                0                     0  74.030  0.185
#
#       색상_b*
# 468   2.770
# 469   2.965
# 470   2.685
# 471   2.685
# 472   1.905
# 473   2.615
# 474   3.075
# 475   2.025
# 1145  2.565
# 1146  3.865
# 1147  4.010
# 1148  3.785
# 1149  1.665
# 1151  2.630
# 1152  2.315
# 3403  2.910
# 3482  3.305
# 3483  3.510
# 3485  2.450

# %%
dix_black_speacal2.iloc[:,28:50]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 468                  1.5                0.75            1.458333  \
# 469                  1.5                0.75            1.458333
# 470                  1.5                0.75            1.458333
# 471                  1.5                0.75            1.458333
# 472                  1.5                0.75            1.458333
# 473                  1.5                0.75            1.458333
# 474                  1.5                0.75            1.458333
# 475                  1.5                0.75            1.458333
# 1145                 0.5                0.50            0.500000
# 1146                 0.5                1.50            0.500000
# 1147                 1.5                0.50            0.500000
# 1148                 1.5                0.50            1.500000
# 1149                 1.5                0.75            0.833333
# 1151                 1.5                1.50            0.500000
# 1152                 1.5                1.50            1.500000
# 3403                 1.5                0.75            1.458333
# 3482                 0.5                0.50            1.500000
# 3483                 0.5                1.50            1.500000
# 3485                 1.5                0.75            0.833333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 468                  135                       10             1.97222  \
# 469                  135                       20             1.97222
# 470                  135                       40             1.97222
# 471                  135                       50             1.97222
# 472                  135                       60             1.97222
# 473                  135                       70             1.97222
# 474                  135                       80             1.97222
# 475                  135                       60             1.97222
# 1145                 135                       60             1.97222
# 1146                 135                       60             1.97222
# 1147                 135                       60             1.97222
# 1148                 135                       60             1.97222
# 1149                 120                       60             1.97222
# 1151                 135                       60             1.97222
# 1152                 135                       60             1.97222
# 3403                 135                       30             1.97222
# 3482                 135                       60             1.97222
# 3483                 135                       60             1.97222
# 3485                 120                       60             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 468            2.0                     4.0                             0.0  \
# 469            2.0                     4.0                             0.0
# 470            2.0                     4.0                             0.0
# 471            2.0                     4.0                             0.0
# 472            2.0                     4.0                             0.0
# 473            2.0                     4.0                             0.0
# 474            2.0                     4.0                             0.0
# 475            2.0                     4.0                             0.0
# 1145           2.0                     4.0                             0.0
# 1146           2.0                     4.0                             0.0
# 1147           2.0                     4.0                             0.0
# 1148           2.0                     4.0                             0.0
# 1149           2.0                     4.0                             0.0
# 1151           2.0                     4.0                             0.0
# 1152           2.0                     4.0                             0.0
# 3403           2.0                     4.0                             0.0
# 3482           2.0                     4.0                             0.0
# 3483           2.0                     4.0                             0.0
# 3485           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  ...  Dianix Red AM-SLR_prop_std
# 468                           0.0  ...                         0.0  \
# 469                           0.0  ...                         0.0
# 470                           0.0  ...                         0.0
# 471                           0.0  ...                         0.0
# 472                           0.0  ...                         0.0
# 473                           0.0  ...                         0.0
# 474                           0.0  ...                         0.0
# 475                           0.0  ...                         0.0
# 1145                          0.0  ...                         0.0
# 1146                          0.0  ...                         0.0
# 1147                          0.0  ...                         0.0
# 1148                          0.0  ...                         0.0
# 1149                          0.0  ...                         0.0
# 1151                          0.0  ...                         0.0
# 1152                          0.0  ...                         0.0
# 3403                          0.0  ...                         0.0
# 3482                          0.0  ...                         0.0
# 3483                          0.0  ...                         0.0
# 3485                          0.0  ...                         0.0
#
#       Dianix Blue AM-2G_prop_std  Synolon Yellow AK_prop_std
# 468                          0.0                         0.0  \
# 469                          0.0                         0.0
# 470                          0.0                         0.0
# 471                          0.0                         0.0
# 472                          0.0                         0.0
# 473                          0.0                         0.0
# 474                          0.0                         0.0
# 475                          0.0                         0.0
# 1145                         0.0                         0.0
# 1146                         0.0                         0.0
# 1147                         0.0                         0.0
# 1148                         0.0                         0.0
# 1149                         0.0                         0.0
# 1151                         0.0                         0.0
# 1152                         0.0                         0.0
# 3403                         0.0                         0.0
# 3482                         0.0                         0.0
# 3483                         0.0                         0.0
# 3485                         0.0                         0.0
#
#       Synolon Red AK_prop_std  Synolon Blue AK_prop_std
# 468                       0.0                       0.0  \
# 469                       0.0                       0.0
# 470                       0.0                       0.0
# 471                       0.0                       0.0
# 472                       0.0                       0.0
# 473                       0.0                       0.0
# 474                       0.0                       0.0
# 475                       0.0                       0.0
# 1145                      0.0                       0.0
# 1146                      0.0                       0.0
# 1147                      0.0                       0.0
# 1148                      0.0                       0.0
# 1149                      0.0                       0.0
# 1151                      0.0                       0.0
# 1152                      0.0                       0.0
# 3403                      0.0                       0.0
# 3482                      0.0                       0.0
# 3483                      0.0                       0.0
# 3485                      0.0                       0.0
#
#       Dorosperse B/K KKL_prop_std  Dianix Black AM-SLR_prop_std
# 468                             0                             1  \
# 469                             0                             1
# 470                             0                             1
# 471                             0                             1
# 472                             0                             1
# 473                             0                             1
# 474                             0                             1
# 475                             0                             1
# 1145                            0                             1
# 1146                            0                             1
# 1147                            0                             1
# 1148                            0                             1
# 1149                            0                             1
# 1151                            0                             1
# 1152                            0                             1
# 3403                            0                             1
# 3482                            0                             1
# 3483                            0                             1
# 3485                            0                             1
#
#       Synolon Black AK-NB_prop_std  Dorosperse Dark Grey KKL_prop_std
# 468                              0                                  0  \
# 469                              0                                  0
# 470                              0                                  0
# 471                              0                                  0
# 472                              0                                  0
# 473                              0                                  0
# 474                              0                                  0
# 475                              0                                  0
# 1145                             0                                  0
# 1146                             0                                  0
# 1147                             0                                  0
# 1148                             0                                  0
# 1149                             0                                  0
# 1151                             0                                  0
# 1152                             0                                  0
# 3403                             0                                  0
# 3482                             0                                  0
# 3483                             0                                  0
# 3485                             0                                  0
#
#       Dianix Grey AM-SLR_prop_std
# 468                             0
# 469                             0
# 470                             0
# 471                             0
# 472                             0
# 473                             0
# 474                             0
# 475                             0
# 1145                            0
# 1146                            0
# 1147                            0
# 1148                            0
# 1149                            0
# 1151                            0
# 1152                            0
# 3403                            0
# 3482                            0
# 3483                            0
# 3485                            0
#
# [19 rows x 22 columns]

# %%
dix_black4=data4[data4["Dianix Black AM-SLR_std"] >= 2.0]

dix_black5 = dix_black4.iloc[:, -3:]

# %%
#dix_black4.iloc[:,28:40]
dix_black4.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 118                               0                                  0  \
# 119                               0                                  0
# 120                               0                                  0
# 121                               0                                  0
# 122                               0                                  0
# ...                             ...                                ...
# 3485                              0                                  0
# 3486                              0                                  0
# 3487                              0                                  0
# 3488                              0                                  0
# 3489                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std    색상_L*   색상_a*
# 118                                 0                     0  28.0300  0.6200  \
# 119                                 0                     0  27.6900  0.6200
# 120                                 0                     0  27.6700  0.4800
# 121                                 0                     0  23.3200  0.3600
# 122                                 0                     0  23.8100  0.4300
# ...                               ...                   ...      ...     ...
# 3485                                0                     0  74.0300  0.1850
# 3486                                0                     0  29.6650  0.5450
# 3487                                0                     0  30.1050  0.5575
# 3488                                0                     0  20.6650 -0.2050
# 3489                                0                     0  21.5175  0.1425
#
#        색상_b*
# 118   0.3100
# 119   0.1000
# 120   0.0900
# 121  -0.1100
# 122  -0.3600
# ...      ...
# 3485  2.4500
# 3486  1.1850
# 3487  0.4175
# 3488 -2.9050
# 3489 -1.0050
#
# [65 rows x 7 columns]

# %%
rgb_list=[]
for index, row in dix_black5.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_black5.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_b2 = pd.concat([dix_black5, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_b2[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()

# %%
dix_YB2= data4[data4["Dianix Yellow Brown AM-R_std"] >= 6.0]
dix_YB2



dix_YB2.iloc[:,0:10]
dix_YB2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 396                               0                                  1  \
# 1024                              0                                  1
# 1025                              0                                  1
# 1026                              0                                  1
# 1027                              0                                  1
# 1028                              0                                  1
# 1029                              0                                  1
# 1030                              0                                  1
# 1031                              0                                  1
# 1032                              0                                  1
# 1033                              0                                  1
# 1034                              0                                  1
# 1035                              0                                  1
# 1036                              0                                  1
# 1037                              0                                  1
# 1038                              0                                  1
# 1039                              0                                  1
# 1040                              0                                  1
# 1041                              0                                  1
# 1042                              0                                  1
# 3470                              0                                  1
# 3471                              0                                  1
# 3472                              0                                  1
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std    색상_L*   색상_a*
# 396                                 0                     0  50.7300  38.685  \
# 1024                                0                     0  50.8050  38.665
# 1025                                0                     0  51.0800  38.565
# 1026                                0                     0  51.2300  38.725
# 1027                                0                     0  50.9400  38.470
# 1028                                0                     0  86.5150   6.045
# 1029                                0                     0  61.6250  30.235
# 1030                                0                     0  50.8850  38.935
# 1031                                0                     0  50.7300  38.955
# 1032                                0                     0  50.8950  38.765
# 1033                                0                     0  50.8100  38.730
# 1034                                0                     0  50.8700  38.600
# 1035                                0                     0  50.9275  38.525
# 1036                                0                     0  51.4000  38.075
# 1037                                0                     0  50.9700  37.935
# 1038                                0                     0  50.9200  38.495
# 1039                                0                     0  51.0900  38.455
# 1040                                0                     0  51.0800  38.170
# 1041                                0                     0  51.0700  38.190
# 1042                                0                     0  50.9550  38.175
# 3470                                0                     0  51.1050  38.605
# 3471                                0                     0  50.9000  38.515
# 3472                                0                     0  50.8850  38.495
#
#         색상_b*
# 396   55.1050
# 1024  55.1400
# 1025  55.3600
# 1026  55.5550
# 1027  55.1400
# 1028  22.5800
# 1029  56.2650
# 1030  55.2650
# 1031  55.2200
# 1032  55.1650
# 1033  55.1600
# 1034  55.1800
# 1035  54.8475
# 1036  55.4900
# 1037  54.8650
# 1038  55.0500
# 1039  55.2350
# 1040  55.1725
# 1041  55.3400
# 1042  54.7800
# 3470  55.4250
# 3471  55.1150
# 3472  55.2200

# %%
dix_YB2.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 396                  1.5                0.75            1.458333  \
# 1024                 0.5                0.50            0.500000
# 1025                 0.5                0.50            1.500000
# 1026                 0.5                1.50            0.500000
# 1027                 1.5                0.50            1.500000
# 1028                 1.5                0.75            0.833333
# 1029                 1.5                0.75            1.250000
# 1030                 1.5                0.75            1.458333
# 1031                 1.5                0.75            1.458333
# 1032                 1.5                0.75            1.458333
# 1033                 1.5                0.75            1.458333
# 1034                 1.5                0.75            1.458333
# 1035                 1.5                0.75            1.458333
# 1036                 1.5                0.75            1.458333
# 1037                 1.5                0.75            1.666667
# 1038                 1.5                1.50            0.500000
# 1039                 1.5                1.50            1.500000
# 1040                 1.5                0.75            1.458333
# 1041                 1.5                0.75            1.458333
# 1042                 1.5                0.75            1.458333
# 3470                 0.5                1.50            1.500000
# 3471                 1.5                0.50            0.500000
# 3472                 1.5                0.75            1.458333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 396                  135                       60             1.97222  \
# 1024                 135                       60             1.97222
# 1025                 135                       60             1.97222
# 1026                 135                       60             1.97222
# 1027                 135                       60             1.97222
# 1028                 120                       60             1.97222
# 1029                 130                       60             1.97222
# 1030                 135                       10             1.97222
# 1031                 135                       20             1.97222
# 1032                 135                       30             1.97222
# 1033                 135                       40             1.97222
# 1034                 135                       50             1.97222
# 1035                 135                       60             1.97222
# 1036                 135                       80             1.97222
# 1037                 140                       60             1.97222
# 1038                 135                       60             1.97222
# 1039                 135                       60             1.97222
# 1040                 135                       60             1.97222
# 1041                 135                       60             1.97222
# 1042                 135                       60             1.97222
# 3470                 135                       60             1.97222
# 3471                 135                       60             1.97222
# 3472                 135                       70             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 396            2.0                     4.0                             0.0  \
# 1024           2.0                     4.0                             0.0
# 1025           2.0                     4.0                             0.0
# 1026           2.0                     4.0                             0.0
# 1027           2.0                     4.0                             0.0
# 1028           2.0                     4.0                             0.0
# 1029           2.0                     4.0                             0.0
# 1030           2.0                     4.0                             0.0
# 1031           2.0                     4.0                             0.0
# 1032           2.0                     4.0                             0.0
# 1033           2.0                     4.0                             0.0
# 1034           2.0                     4.0                             0.0
# 1035           2.0                     4.0                             0.0
# 1036           2.0                     4.0                             0.0
# 1037           2.0                     4.0                             0.0
# 1038           2.0                     4.0                             0.0
# 1039           2.0                     4.0                             0.0
# 1040           2.0                     4.0                             0.0
# 1041           2.0                     4.0                             0.0
# 1042           2.0                     4.0                             0.0
# 3470           2.0                     4.0                             0.0
# 3471           2.0                     4.0                             0.0
# 3472           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  Dorosperse Blue KKL_prop_std
# 396                           0.0                           0.0  \
# 1024                          0.0                           0.0
# 1025                          0.0                           0.0
# 1026                          0.0                           0.0
# 1027                          0.0                           0.0
# 1028                          0.0                           0.0
# 1029                          0.0                           0.0
# 1030                          0.0                           0.0
# 1031                          0.0                           0.0
# 1032                          0.0                           0.0
# 1033                          0.0                           0.0
# 1034                          0.0                           0.0
# 1035                          0.0                           0.0
# 1036                          0.0                           0.0
# 1037                          0.0                           0.0
# 1038                          0.0                           0.0
# 1039                          0.0                           0.0
# 1040                          0.0                           0.0
# 1041                          0.0                           0.0
# 1042                          0.0                           0.0
# 3470                          0.0                           0.0
# 3471                          0.0                           0.0
# 3472                          0.0                           0.0
#
#       Dianix Yellow AM-2R_prop_std
# 396                            0.0
# 1024                           0.0
# 1025                           0.0
# 1026                           0.0
# 1027                           0.0
# 1028                           0.0
# 1029                           0.0
# 1030                           0.0
# 1031                           0.0
# 1032                           0.0
# 1033                           0.0
# 1034                           0.0
# 1035                           0.0
# 1036                           0.0
# 1037                           0.0
# 1038                           0.0
# 1039                           0.0
# 1040                           0.0
# 1041                           0.0
# 1042                           0.0
# 3470                           0.0
# 3471                           0.0
# 3472                           0.0

# %%
rgb_list=[]
for index, row in dix_YB3.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_YB3.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_yb = pd.concat([dix_YB3, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_yb[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()

# %%
dix_Gray2=data4[data4["Dianix Grey AM-SLR_std"] >= 4.0]
dix_Gray2.nunique()
dix_Gray2.iloc[:,0:10]
dix_Gray2.iloc[:,50:60]
# Out:
#       Synolon Dark Grey AK_prop_std  Dianix Yellow Brown AM-R_prop_std
# 75                                0                                  0  \
# 76                                0                                  0
# 77                                0                                  0
# 78                                0                                  0
# 79                                0                                  0
# 80                                0                                  0
# 81                                0                                  0
# 82                                0                                  0
# 414                               0                                  0
# 415                               0                                  0
# 1094                              0                                  0
# 1095                              0                                  0
# 1096                              0                                  0
# 1097                              0                                  0
# 1098                              0                                  0
# 1099                              0                                  0
# 1100                              0                                  0
# 1101                              0                                  0
# 1102                              0                                  0
# 1103                              0                                  0
# 1104                              0                                  0
# 1105                              0                                  0
# 1106                              0                                  0
# 1107                              0                                  0
# 1108                              0                                  0
# 1109                              0                                  0
# 1110                              0                                  0
# 1111                              0                                  0
# 1112                              0                                  0
# 1113                              0                                  0
# 1114                              0                                  0
# 1115                              0                                  0
# 1116                              0                                  0
# 1117                              0                                  0
# 1118                              0                                  0
# 3353                              0                                  0
# 3474                              0                                  0
# 3475                              0                                  0
#
#       Dorosperse Brown K-3LR_prop_std  Synofast 28_prop_std    색상_L*   색상_a*
# 75                                  0                     0  26.9000  0.1500  \
# 76                                  0                     0  26.9000  0.1100
# 77                                  0                     0  26.9000  0.2000
# 78                                  0                     0  25.0600  0.2000
# 79                                  0                     0  22.4500  0.0900
# 80                                  0                     0  23.6900  0.1100
# 81                                  0                     0  22.9200  0.1200
# 82                                  0                     0  22.6300  0.1400
# 414                                 0                     0  30.1400  0.2850
# 415                                 0                     0  24.6650  0.0500
# 1094                                0                     0  25.9725  0.3750
# 1095                                0                     0  29.8075  0.3425
# 1096                                0                     0  29.2600  0.2900
# 1097                                0                     0  24.5300  0.0650
# 1098                                0                     0  24.5050  0.0500
# 1099                                0                     0  24.4500  0.0700
# 1100                                0                     0  24.5250  0.1000
# 1101                                0                     0  24.5650  0.0500
# 1102                                0                     0  24.3650  0.0550
# 1103                                0                     0  79.8900 -0.1300
# 1104                                0                     0  79.7000 -0.1500
# 1105                                0                     0  39.5000  0.5750
# 1106                                0                     0  24.0400 -0.2500
# 1107                                0                     0  24.0150 -0.0800
# 1108                                0                     0  24.0850  0.0600
# 1109                                0                     0  24.1100  0.1050
# 1110                                0                     0  21.7450  0.1550
# 1111                                0                     0  24.1200  0.0950
# 1112                                0                     0  24.1100  0.0850
# 1113                                0                     0  24.5100  0.1950
# 1114                                0                     0  24.6400  0.0400
# 1115                                0                     0  24.5550  0.0700
# 1116                                0                     0  24.4025  0.1700
# 1117                                0                     0  24.7700  0.1350
# 1118                                0                     0  24.5950  0.1600
# 3353                                0                     0  24.1700  0.1000
# 3474                                0                     0  29.9250  0.3200
# 3475                                0                     0  24.0650  0.0250
#
#        색상_b*
# 75   -1.6500
# 76   -1.5900
# 77   -1.6300
# 78   -1.6800
# 79   -1.6200
# 80   -1.6600
# 81   -1.6100
# 82   -1.7100
# 414  -1.1850
# 415  -1.2900
# 1094 -0.8025
# 1095 -1.2050
# 1096 -1.1500
# 1097 -1.2650
# 1098 -1.3700
# 1099 -1.2400
# 1100 -1.3400
# 1101 -1.3450
# 1102 -1.2850
# 1103  0.9600
# 1104  1.1900
# 1105 -0.5700
# 1106 -1.4200
# 1107 -1.3700
# 1108 -1.3350
# 1109 -1.2950
# 1110 -1.0825
# 1111 -1.2700
# 1112 -1.2850
# 1113 -1.2450
# 1114 -1.3450
# 1115 -1.3250
# 1116 -1.3625
# 1117 -1.3450
# 1118 -1.3050
# 3353 -1.6400
# 3474 -1.2800
# 3475 -1.2900

# %%
dix_Gray2.iloc[:,28:40]
# Out:
#       Lab 염색 상승속도 #1_std  Lab 염색 상승속도 #2_std  Lab 염색 상승속도 #3_std
# 75                   1.5                0.75            1.500000  \
# 76                   1.5                0.75            1.500000
# 77                   1.5                0.75            1.500000
# 78                   1.5                0.75            1.500000
# 79                   1.5                0.75            1.500000
# 80                   1.5                0.75            1.500000
# 81                   1.5                0.75            1.500000
# 82                   1.5                0.75            1.500000
# 414                  1.5                0.75            1.458333
# 415                  1.5                0.75            1.458333
# 1094                 1.5                0.75            1.458333
# 1095                 1.5                0.75            1.458333
# 1096                 1.5                0.75            1.458333
# 1097                 0.5                0.50            0.500000
# 1098                 0.5                0.50            1.500000
# 1099                 0.5                1.50            0.500000
# 1100                 0.5                1.50            1.500000
# 1101                 1.5                0.50            0.500000
# 1102                 1.5                0.50            1.500000
# 1103                 1.5                0.75            0.833333
# 1104                 1.5                0.75            0.833333
# 1105                 1.5                0.75            1.250000
# 1106                 1.5                0.75            1.458333
# 1107                 1.5                0.75            1.458333
# 1108                 1.5                0.75            1.458333
# 1109                 1.5                0.75            1.458333
# 1110                 1.5                0.75            1.458333
# 1111                 1.5                0.75            1.458333
# 1112                 1.5                0.75            1.458333
# 1113                 1.5                0.75            1.666667
# 1114                 1.5                1.50            0.500000
# 1115                 1.5                1.50            1.500000
# 1116                 1.5                0.75            1.458333
# 1117                 1.5                0.75            1.458333
# 1118                 1.5                0.75            1.458333
# 3353                 1.5                0.75            1.500000
# 3474                 1.5                0.75            1.458333
# 3475                 1.5                0.75            1.458333
#
#       Lab 염색 상승온도 #3_std  Lab 염색 상승온도 #3 유지시간_std  Lab 염색 하강속도 #1_std
# 75                   136                       60             2.00000  \
# 76                   136                       60             2.00000
# 77                   136                       60             2.00000
# 78                   136                       60             2.00000
# 79                   136                       60             2.00000
# 80                   136                       60             2.00000
# 81                   136                       60             2.00000
# 82                   136                       60             2.00000
# 414                  135                       60             1.97222
# 415                  135                       60             1.97222
# 1094                 135                       60             1.97222
# 1095                 135                       60             1.97222
# 1096                 135                       60             1.97222
# 1097                 135                       60             1.97222
# 1098                 135                       60             1.97222
# 1099                 135                       60             1.97222
# 1100                 135                       60             1.97222
# 1101                 135                       60             1.97222
# 1102                 135                       60             1.97222
# 1103                 120                       60             1.97222
# 1104                 120                       60             1.97222
# 1105                 130                       60             1.97222
# 1106                 135                       10             1.97222
# 1107                 135                       20             1.97222
# 1108                 135                       40             1.97222
# 1109                 135                       50             1.97222
# 1110                 135                       60             1.97222
# 1111                 135                       70             1.97222
# 1112                 135                       80             1.97222
# 1113                 140                       60             1.97222
# 1114                 135                       60             1.97222
# 1115                 135                       60             1.97222
# 1116                 135                       60             1.97222
# 1117                 135                       60             1.97222
# 1118                 135                       60             1.97222
# 3353                 136                       60             2.00000
# 3474                 135                       60             1.97222
# 3475                 135                       30             1.97222
#
#       후처리_NaOH_std  후처리_Sera Con M-FAS_std  Dorosperse Yellow KKL_prop_std
# 75             2.0                     2.0                             0.0  \
# 76             2.0                     2.0                             0.0
# 77             2.0                     2.0                             0.0
# 78             2.0                     2.0                             0.0
# 79             2.0                     2.0                             0.0
# 80             2.0                     2.0                             0.0
# 81             2.0                     2.0                             0.0
# 82             2.0                     2.0                             0.0
# 414            2.0                     4.0                             0.0
# 415            2.0                     4.0                             0.0
# 1094           2.0                     4.0                             0.0
# 1095           2.0                     4.0                             0.0
# 1096           2.0                     4.0                             0.0
# 1097           2.0                     4.0                             0.0
# 1098           2.0                     4.0                             0.0
# 1099           2.0                     4.0                             0.0
# 1100           2.0                     4.0                             0.0
# 1101           2.0                     4.0                             0.0
# 1102           2.0                     4.0                             0.0
# 1103           2.0                     4.0                             0.0
# 1104           2.0                     4.0                             0.0
# 1105           2.0                     4.0                             0.0
# 1106           2.0                     4.0                             0.0
# 1107           2.0                     4.0                             0.0
# 1108           2.0                     4.0                             0.0
# 1109           2.0                     4.0                             0.0
# 1110           2.0                     4.0                             0.0
# 1111           2.0                     4.0                             0.0
# 1112           2.0                     4.0                             0.0
# 1113           2.0                     4.0                             0.0
# 1114           2.0                     4.0                             0.0
# 1115           2.0                     4.0                             0.0
# 1116           2.0                     4.0                             0.0
# 1117           2.0                     4.0                             0.0
# 1118           2.0                     4.0                             0.0
# 3353           2.0                     2.0                             0.0
# 3474           2.0                     4.0                             0.0
# 3475           2.0                     4.0                             0.0
#
#       Dorosperse Red KKL_prop_std  Dorosperse Blue KKL_prop_std
# 75                            0.0                           0.0  \
# 76                            0.0                           0.0
# 77                            0.0                           0.0
# 78                            0.0                           0.0
# 79                            0.0                           0.0
# 80                            0.0                           0.0
# 81                            0.0                           0.0
# 82                            0.0                           0.0
# 414                           0.0                           0.0
# 415                           0.0                           0.0
# 1094                          0.0                           0.0
# 1095                          0.0                           0.0
# 1096                          0.0                           0.0
# 1097                          0.0                           0.0
# 1098                          0.0                           0.0
# 1099                          0.0                           0.0
# 1100                          0.0                           0.0
# 1101                          0.0                           0.0
# 1102                          0.0                           0.0
# 1103                          0.0                           0.0
# 1104                          0.0                           0.0
# 1105                          0.0                           0.0
# 1106                          0.0                           0.0
# 1107                          0.0                           0.0
# 1108                          0.0                           0.0
# 1109                          0.0                           0.0
# 1110                          0.0                           0.0
# 1111                          0.0                           0.0
# 1112                          0.0                           0.0
# 1113                          0.0                           0.0
# 1114                          0.0                           0.0
# 1115                          0.0                           0.0
# 1116                          0.0                           0.0
# 1117                          0.0                           0.0
# 1118                          0.0                           0.0
# 3353                          0.0                           0.0
# 3474                          0.0                           0.0
# 3475                          0.0                           0.0
#
#       Dianix Yellow AM-2R_prop_std
# 75                             0.0
# 76                             0.0
# 77                             0.0
# 78                             0.0
# 79                             0.0
# 80                             0.0
# 81                             0.0
# 82                             0.0
# 414                            0.0
# 415                            0.0
# 1094                           0.0
# 1095                           0.0
# 1096                           0.0
# 1097                           0.0
# 1098                           0.0
# 1099                           0.0
# 1100                           0.0
# 1101                           0.0
# 1102                           0.0
# 1103                           0.0
# 1104                           0.0
# 1105                           0.0
# 1106                           0.0
# 1107                           0.0
# 1108                           0.0
# 1109                           0.0
# 1110                           0.0
# 1111                           0.0
# 1112                           0.0
# 1113                           0.0
# 1114                           0.0
# 1115                           0.0
# 1116                           0.0
# 1117                           0.0
# 1118                           0.0
# 3353                           0.0
# 3474                           0.0
# 3475                           0.0

# %%
rgb_list=[]
for index, row in dix_Gray3.iterrows():
    R,G,B=lab2rgb(row["색상_L*"],row["색상_a*"],row["색상_b*"])
    rgb_list.append([R,G,B])

rgb_df= pd.DataFrame(rgb_list,index=dix_Gray3.index,columns=["R","G","B"])

# 원래 데이터프레임에 RGB 데이터프레임을 연결합니다.
df_rgb_G = pd.concat([dix_Gray3, rgb_df], axis=1,)

# %%
# 데이터프레임의 'R', 'G', 'B' 컬럼만 정규화합니다.
df_rgb_normalized = df_rgb_G[['R', 'G', 'B']] / 255

# 서브플롯의 크기를 결정합니다. 여기서는 5개의 열을 갖는 그리드로 설정합니다.
n_rows = len(df_rgb_normalized) // 5 + 1
n_cols = 5

# 시각화를 위한 준비
fig, axs = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*3))  # 전체 그림의 크기를 조정합니다.

# axs가 1차원 배열인 경우 2차원 배열로 변환합니다.
if n_rows == 1:
    axs = np.array([axs])

# 모든 서브플롯을 순회하며 RGB 색상을 표시합니다.
for i, (index, row) in enumerate(df_rgb_normalized.iterrows()):
    ax = axs[i // n_cols, i % n_cols]
    ax.imshow([[row.values]])  # RGB 색상으로 사각형을 그립니다.
    ax.set_title(f'Index: {index}')  # 서브플롯 위에 데이터프레임 인덱스를 표시합니다.
    ax.axis('off')  # 축을 숨깁니다.

# 남은 서브플롯을 숨깁니다.
for j in range(i+1, n_rows*n_cols):
    axs[j // n_cols, j % n_cols].axis('off')

plt.tight_layout()
plt.show()
