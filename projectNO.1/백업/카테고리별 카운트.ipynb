# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("전처리저장용.csv")

# %%
category_counts
# Out:
# 카테고리
# 프로그래밍       46928
# 데이터 사이언스    24444
# 일러스트        14121
# 업무 생산성      12921
# 영상/3D       12801
# 마케팅         11827
# 부동산/금융       9990
# 디자인          9311
# 투자/재테크       2325
# 부업/창업         998
# Name: count, dtype: int64

# %%
# 원형 그래프 그리기
plt.figure(figsize=(10, 10))
patches, text, autotext = plt.pie(category_counts, labels=None, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # 원형을 유지하기 위해 가로세로 비율을 동일하게 설정

# 퍼센트 값 직접 표시
for i, (p, t) in enumerate(zip(patches, autotext)):
    if category_counts[i] < 50:  # 비율이 50% 미만인 경우에만 표시
        t.set_text('')
        percentage = '{:.1f}%'.format(category_counts[i] / sum(category_counts) * 100)
        plt.text(p.center[0], p.center[1], percentage, ha='center', va='center')

plt.title('카테고리별 판매수')

# 범례 표시
plt.legend(patches, category_counts.index, loc='best')

plt.show()
